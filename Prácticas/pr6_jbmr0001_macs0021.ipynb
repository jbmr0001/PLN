# %% [markdown]
# # **Procesamiento del Lenguaje Natural**
# ## *Práctica 6 - Aprendizaje no supervisado*

# %% [markdown]
# ## Objetivos
#
# *   Conocer lo que es el aprendizaje automático y clasificar textos con enfoques no supervisados haciendo uso de la librería Sklearn de Python.

# %% [markdown]
# ## Aprendizaje automático
#
# El aprendizaje automático (machine learning en inglés) es una técnica de la inteligencia artificial que crea modelos que aprenden automáticamente. Aprender en este contexto quiere decir identificar patrones complejos en millones de datos. La máquina que realmente aprende es un algoritmo que revisa los datos y es capaz de predecir comportamientos futuros.

# %% [markdown]
# ### Aprendizaje no supervisado
#
# Cuando se trata de problemas del mundo real, la mayoría de las veces, los datos no vienen con etiquetas predefinidas, así que intentaremos desarrollar modelos de aprendizaje automático que puedan etiquetar correctamente estos datos, encontrando por sí mismos algunos puntos en común en las características.

# %% [markdown]
# #### 1. Funcionamiento
#
# Para comprender el funcionamiento del aprendizaje no supervisado se acudirá a un ejemplo donde tenemos un conjunto de datos sin etiquetar. A este conjunto de datos le extraemos sus características en vectores numéricos y con esto, entrenamos el algoritmo de aprendizaje automático con el fin de que busque patrones entre los datos.
#
#
# En el siguiente ejemplo podemos ver que el algoritmo nos genera un modelo (rombo azul) que es generado por el algoritmo (círculo azul). El conjunto de entrenamiento será en nuestro caso textos a los que sacaremos el vector de características (líneas verticales azules). Al modelo podemos proporcionarle nuevos conjuntos de datos (conjunto de test) al que también sacaremos sus características para que nos agrupe los nuevos elementos que nunca ha visto antes usando el modelo generado anteriormente. En este ejemplo podemos ver una clasificación no supervisada de frutas, el algoritmo finalmente las agrupa según su categoría:
#
# <img src="https://www.diegocalvo.es/wp-content/uploads/2019/03/aprendizaje_no_supervisado.png" width="800" height="500" />

# %% [markdown]
# #### 2. Clustering
#
# En términos básicos, el objetivo de la agrupación es encontrar diferentes grupos dentro de los elementos de los datos. Para ello, los algoritmos de agrupamiento encuentran la estructura en los datos de manera que los elementos del mismo clúster (o grupo) sean más similares entre sí que con los de clústeres diferentes.
#
# <img src="https://www.diegocalvo.es/wp-content/uploads/2019/03/clustering.png" width="300" height="200" />

# %% [markdown]
# Algunos de los algoritmos de agrupación más comunes son:
#
# *   K-Means
# *   Clusterización Jerárquica
# *   Density Based Scan Clustering (DBSCAN)
# *   Modelo de Agrupamiento Gaussiano
#
# Nosotros en clase implementaremos el algoritmo **K-means**.
#
# El objetivo de este algoritmo es el de encontrar «K» grupos (clusters) entre los datos.
#
#
# <img src="https://www.gatevidyalay.com/wp-content/uploads/2020/01/K-Means-Clustering.png" width="500" height="300" />

# %% [markdown]
# Para implementar este método, debemos añadir las librerías necesarias (si es necesario se deben instalar sklearn) scikit-learn:

# %%
from sklearn.cluster import KMeans

# %% [markdown]
#  Añadimos los textos en una lista de Python:

# %%
documents = ["This little kitty came to play when I was eating at a restaurant.",
             "Merley has the best squooshy kitten belly.",
             "Google Translate app is incredible.",
             "If you open 100 tab in google you get a smiley face.",
             "Best cat photo I've ever taken.",
             "Climbing ninja cat.",
             "Impressed with google map feedback.",
             "Key promoter extension for Google Chrome."]

# %% [markdown]
# #### Vectores de características: TF-IDF
#
# El método TfidfVectorizer utiliza un vocabulario para generar una matriz de Tf-Idf (frecuencia de término - frecuencia inversa de documento).
#
# Tf-idf es una medida numérica que expresa cuánto de relevante es una palabra para un documento de una colección. Esta medida se utiliza a menudo como un factor de ponderación en la recuperación de información y la minería de texto.
#
# Para ello primero definiremos la clase **TfidfVectorizer()** y después usaremos el método **.fit_transform()** con el que obtendremos el vector de características del los textos de entrenamiento:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

# %%
X
# Out:
# <8x48 sparse matrix of type '<class 'numpy.float64'>'
# 	with 53 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Creamos el modelo con la clase **KMeans()** usando los parámetros que sean convenientes (podéis probar varios parámetros usado la documentación) y entrenamos el modelo k-means con el método **.fit()**. Finalmente, k es el número de grupos que queremos obtener:

# %%
k = 2
model = KMeans(n_clusters=k)
model.fit(X) # entrenamiento
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %% [markdown]
# Ahora, podemos ver información de los cluster que ha creado el modelo:

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()
for i in range(k):
  print("\nCluster:", i)
  for ind in order_centroids[i, :10]:
    print(' \t', terms[ind])
# Out:
# Top terms per cluster:
#
# Cluster: 0
#  	 google
#  	 you
#  	 app
#  	 translate
#  	 feedback
#  	 impressed
#  	 incredible
#  	 is
#  	 with
#  	 map
#
# Cluster: 1
#  	 cat
#  	 best
#  	 ninja
#  	 climbing
#  	 photo
#  	 ve
#  	 ever
#  	 taken
#  	 squooshy
#  	 kitten

# %% [markdown]
# A continuación, una vez que tenemos el modelo generado, vamos a predecir en qué grupo o cluster encajaría un nuevo texto usando el modelo anteriormente creado.
#
# Para ello introducimos un nuevo texto en un vector, sacamos sus vectores de características con el modelo Tf-Idf generado anteriormente usando el método **.transform()** y por último obtenemos la predicción del modelo usando el método **.predict()**:

# %%
text = ["My chrome browser to open."]
Y = vectorizer.transform(text)
prediction = model.predict(Y)
print('Cluster donde encajaría:', prediction)
text = ["Drago's cat is cute."]
Y = vectorizer.transform(text)
prediction = model.predict(Y)
print('Cluster donde encajaría:', prediction)
# Out:
# Cluster donde encajaría: [0]
# Cluster donde encajaría: [1]

# %% [markdown]
# ## Tutoriales
#
# Tutorial sobre algoritmos no supervisados: https://cutt.ly/CtYl63Y
#
# Tutorial sobre K-medias: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
#
# Tutorial sobre Tf-Idf: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %% [markdown]
# ## Ejercicio
#
# El resultado de esta práctica deberá entregarse en PLATEA y tiene como límite de entrega las **23:59 horas del día 16 de abril de 2023**. Se entregará este mismo notebook de extensión *.ipynb* y se renombrará de la siguiente forma: pr6_usuario1_usuario2.ipynb. Sustituye "usuario1" y "usuario2" por el alias de vuestro correo.
#
# Utiliza la colección "colección_SFU_PLN" disponible en la carpeta Material complementario de Docencia Virtual para crear un modelo K-means.
#
# Dado que el corpus está dividido en 8 categorías (books, cars, music, etc) usaremos k = 8 para la agrupación.
#
#
# Para ello, procesa el texto de cada documento de la colección:
# * Tokeniza el texto
# * Elimina palabras vacías
# * Reduce las palabras a su raíz
# * Cambia el texto a minúscula
#
# Posteriormente, utiliza el método visto en clase de Tf-Idf sobre los documentos ya procesados y entrena el modelo k-means.
#
# Predice el grupo/cluster de estos nuevos textos:
#
# ```
# My accommodation is near the river and the mountain.
# I have John Lennon's CD at home.
# The most interesting sections are the last ones.
# I enjoyed with the last essay of Pinker.
# The steering of the car is very hard.
# ```
#
# **NOTA**: es importante procesar los textos que queremos predecir de la misma manera que hemos procesado todos los documentos de la colección para que el modelo puedan encontrar las mismas palabras.

# %% [markdown]
# **Autores de la práctica:** Juan Bautista Muñoz Ruiz jbmr0001@red.ujaen.es Marco Antonio Carrión Soriano macs0021@red.ujaen.es

# %%
from google.colab import drive  #Montamos el drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #Abrimos la carpeta
path = os.chdir("/content/drive/MyDrive/PLN/P6")
os.getcwd()
# Out:
# '/content/drive/MyDrive/PLN/P6'

# %%
def getCodificacion(texto): #Función para calcular el encoding con la libreria chardet
  import chardet

  with open(texto, 'rb') as f:
    resultado = chardet.detect(f.read())

  return resultado['encoding']

# %%
########################CARGA DE DATOS##########################
import os #Abrimos la carpeta
path = os.chdir("/content/drive/MyDrive/PLN/P6")
os.getcwd()

import glob   #Lectura y procesado de los archivos
import chardet

mapa ={}
for carpeta in os.listdir():
  os.chdir(carpeta) # Recorremos cada directorio y leemos los archivos
  archivosProcesados=[]
  mapa[carpeta]=archivosProcesados
  for filename in glob.glob('*.txt'):  #Lectura de todos los archivos de la carpeta con la libreria glob
    with open(os.path.join(os.getcwd(), filename), 'r') as f:
     print(carpeta,"/",filename," Leído",end=" ")
     # Calculamos el encoding del archivo con libería chardet
     codificacion=getCodificacion(filename)
     fichero = open(f.name,encoding=codificacion) # Leemos el archivo en su codificación
     mapa[carpeta].append(fichero.read())
  os.chdir('..') #Volvemos al directorio padre
# Out:
# MOVIES / yes9.txt  Leído MOVIES / no5.txt  Leído MOVIES / yes20.txt  Leído MOVIES / no1.txt  Leído MOVIES / no3.txt  Leído MOVIES / yes12.txt  Leído MOVIES / yes18.txt  Leído MOVIES / yes15.txt  Leído MOVIES / yes5.txt  Leído MOVIES / no14.txt  Leído MOVIES / yes17.txt  Leído MOVIES / no9.txt  Leído MOVIES / no12.txt  Leído MOVIES / yes2.txt  Leído MOVIES / yes4.txt  Leído MOVIES / yes7.txt  Leído MOVIES / yes13.txt  Leído MOVIES / no16.txt  Leído MOVIES / no10.txt  Leído MOVIES / no17.txt  Leído MOVIES / no20.txt  Leído MOVIES / yes25.txt  Leído MOVIES / yes1.txt  Leído MOVIES / no7.txt  Leído MOVIES / no24.txt  Leído MOVIES / no19.txt  Leído MOVIES / yes8.txt  Leído MOVIES / no15.txt  Leído MOVIES / yes6.txt  Leído MOVIES / yes24.txt  Leído MOVIES / yes11.txt  Leído MOVIES / no2.txt  Leído MOVIES / no21.txt  Leído MOVIES / no25.txt  Leído MOVIES / no22.txt  Leído MOVIES / yes10.txt  Leído MOVIES / yes16.txt  Leído MOVIES / yes19.txt  Leído MOVIES / yes21.txt  Leído MOVIES / yes14.txt  Leído MOVIES / no23.txt  Leído MOVIES / yes23.txt  Leído MOVIES / yes22.txt  Leído MOVIES / no6.txt  Leído MOVIES / no4.txt  Leído MOVIES / yes3.txt  Leído MOVIES / no13.txt  Leído MOVIES / no8.txt  Leído MOVIES / no18.txt  Leído MOVIES / no11.txt  Leído PHONES / no11.txt  Leído PHONES / no10.txt  Leído PHONES / no18.txt  Leído PHONES / no17.txt  Leído PHONES / no13.txt  Leído PHONES / no12.txt  Leído PHONES / yes20.txt  Leído PHONES / yes6.txt  Leído PHONES / no5.txt  Leído PHONES / yes10.txt  Leído PHONES / no7.txt  Leído PHONES / yes22.txt  Leído PHONES / no22.txt  Leído PHONES / yes1.txt  Leído PHONES / no19.txt  Leído PHONES / yes5.txt  Leído PHONES / yes9.txt  Leído PHONES / no3.txt  Leído PHONES / yes7.txt  Leído PHONES / yes13.txt  Leído PHONES / no24.txt  Leído PHONES / yes21.txt  Leído PHONES / no20.txt  Leído PHONES / yes23.txt  Leído PHONES / yes15.txt  Leído PHONES / no9.txt  Leído PHONES / yes14.txt  Leído PHONES / yes2.txt  Leído PHONES / yes3.txt  Leído PHONES / yes8.txt  Leído PHONES / no6.txt  Leído PHONES / no2.txt  Leído PHONES / yes25.txt  Leído PHONES / yes11.txt  Leído PHONES / no25.txt  Leído PHONES / yes17.txt  Leído PHONES / no4.txt  Leído PHONES / no21.txt  Leído PHONES / yes19.txt  Leído PHONES / yes4.txt  Leído PHONES / no23.txt  Leído PHONES / yes24.txt  Leído PHONES / yes12.txt  Leído PHONES / yes18.txt  Leído PHONES / no8.txt  Leído PHONES / yes16.txt  Leído PHONES / no15.txt  Leído PHONES / no16.txt  Leído PHONES / no14.txt  Leído PHONES / no1.txt  Leído HOTELS / yes19.txt  Leído HOTELS / yes6.txt  Leído HOTELS / yes7.txt  Leído HOTELS / no25.txt  Leído HOTELS / yes16.txt  Leído HOTELS / no7.txt  Leído HOTELS / no20.txt  Leído HOTELS / yes11.txt  Leído HOTELS / yes23.txt  Leído HOTELS / yes2.txt  Leído HOTELS / yes14.txt  Leído HOTELS / yes22.txt  Leído HOTELS / no6.txt  Leído HOTELS / yes15.txt  Leído HOTELS / no10.txt  Leído HOTELS / no11.txt  Leído HOTELS / yes12.txt  Leído HOTELS / no16.txt  Leído HOTELS / yes5.txt  Leído HOTELS / yes10.txt  Leído HOTELS / yes1.txt  Leído HOTELS / yes24.txt  Leído HOTELS / yes8.txt  Leído HOTELS / yes21.txt  Leído HOTELS / no13.txt  Leído HOTELS / yes4.txt  Leído HOTELS / yes25.txt  Leído HOTELS / yes17.txt  Leído HOTELS / no2.txt  Leído HOTELS / no21.txt  Leído HOTELS / no14.txt  Leído HOTELS / yes3.txt  Leído HOTELS / no9.txt  Leído HOTELS / no22.txt  Leído HOTELS / yes18.txt  Leído HOTELS / no1.txt  Leído HOTELS / no4.txt  Leído HOTELS / yes20.txt  Leído HOTELS / no15.txt  Leído HOTELS / no12.txt  Leído HOTELS / no5.txt  Leído HOTELS / yes13.txt  Leído HOTELS / no23.txt  Leído HOTELS / no8.txt  Leído HOTELS / no24.txt  Leído HOTELS / no19.txt  Leído HOTELS / no3.txt  Leído HOTELS / no17.txt  Leído HOTELS / no18.txt  Leído HOTELS / yes9.txt  Leído COMPUTERS / yes1.txt  Leído COMPUTERS / no17.txt  Leído COMPUTERS / no14.txt  Leído COMPUTERS / no6.txt  Leído COMPUTERS / no5.txt  Leído COMPUTERS / yes2.txt  Leído COMPUTERS / yes4.txt  Leído COMPUTERS / yes18.txt  Leído COMPUT ...

# %%
import spacy.cli # Cargamos spacy
spacy.cli.download("en_core_web_sm")

import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
####################PROCESADO DE ARCHIVOS##########################
mapaProcesado={}
for etiqueta in mapa.items():
  lista = []
  mapaProcesado[etiqueta[0]]=lista
  for archivo in etiqueta[1]:
    procesado=nlp(archivo)
    for token in procesado:
      if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
        mapaProcesado[etiqueta[0]].append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula

# %%
print("Archivos procesados:")
for etiqueta in mapaProcesado:
  print(etiqueta,mapaProcesado[etiqueta])
# Out:
# Archivos procesados:
# MOVIES ['plot', 'detail', 'opinion', 'reveal', 'major', 'detail', 'movie', 'plot', 'rest', 'word', 'good', 'movie', 'perfect', 'film', 'see', 'succeed', 'level', 'set', 'attain', 'review', 'know', 'story', 'cruise', 'civil', 'war', 'hero', 'drown', 'sin', 'liquor', 'chance', 'atrocity', 'see', 'native', 'americans', 'gets', 'hire', 'train', 'new', 'western', 'style', 'army', 'emperor', 'japan', 'gets', 'capture', 'fail', 'attempt', 'defeat', 'samurai', 'rebellion', 'movie', 'honestly', 'look', 'forward', 'movie', 'year', 'force', 'reluctant', 'wife', 'interest', 'leave', 'theatre', 'happily', 'surprised', 'high', 'expectation', 'disappoint', 'story', 'fictional', 'disregard', 'historically', 'correct', 'complaint', 'read', 'director', 'say', 'upfront', 'try', 'extremely', 'accurate', 'thing', 'era', 'story', 'true', 'yes', 'predictable', 'moment', 'distract', 'enjoy', 'epic', 'tale', 'costumes', 'win', 'oscar', 'far', 'exquiste', 'creation', 'see', 'year', 'course', 'talk', 'samurai', 'armor', 'foremost', 'cruise', 'promotional', 'material', 'good', 'see', 'act', 'wise', 'cruise', 'stay', 'game', 'think', 'oscar', 'worthy', 'despite', 'training', 'role', 'well', 'favorite', 'performance', 'jerry', 'maguire', 'minority', 'report', 'interview', 'vampire', 'movie', 'fall', 'right', 'line', 'perform', 'good', 'character', 'transition', 'torture', 'past', 'appreciation', 'earnest', 'learning', 'samurai', 'way', 'support', 'character', 'good', 'ken', 'watanabe', 'nominate', 'deliver', 'wide', 'range', 'warrior', 'strength', 'father', 'compassion', 'plenty', 'masterfully', 'craft', 'physical', 'special', 'effect', 'visual', 'effect', 'honestly', 'yes', 'certainly', 'conceive', 'feel', 'see', 'action', 'look', 'entirely', 'real', 'natural', 'long', 'time', 'blow', 'away', 'intense', 'battle', 'scene', 'samurai', 'gear', 'fighting', 'ninjas', 'yes', 'lethal', 'imagine', 'see', 'samurai', 'sword', 'wield', 'amazing', 'skill', 'film', 'choreography', 'fight', 'especially', 'opening', 'attack', 'ninja', 'raid', 'breathtake', 'actually', 'cool', 'grisly', 'death', 'leave', 'feel', 'bit', 'uneasy', 'mean', 'kill', 'person', 'utterly', 'horrible', 'war', 'devestation', 'leave', 'completely', 'de', 'sensitized', 'forget', 'mention', 'gorgeous', 'cinematagraphy', 'score', 'new', 'beautiful', 'venue', 'new', 'zealand', 'truly', 'believe', 'look', 'ancient', 'japan', 'movie', 'witness', 'jaw', 'drop', 'landscape', 'big', 'fan', 'hans', 'zimmer', 'black', 'hawk', 'gladiator', 'score', 'job', 'blend', 'grand', 'eclectic', 'new', 'endeavor', 'soundtrack', 'purchase', 'time', 'awhile', 'actually', 'experience', 'music', 'film', 'film', 'main', 'theme', 'spirit', 'gladiator', 'mohicans', 'obviously', 'far', 'east', 'influence', 'lush', 'rich', 'emotionally', 'charge', 'piece', 'music', 'caveat', 'ending', 'lose', 'movie', 'momentum', 'feel', 'wishy', 'washy', 'rush', 'clear', 'possible', 'lose', 'end', 'story', 'writer', 'know', 'properly', 'close', 'stamp', 'typical', 'hollywood', 'hero', 'end', 'spoiler', 'skip', 'ahead', 'begin', 'rant', 'ridiculous', 'samurai', 'gets', 'kill', 'battlefield', 'algren', 'especially', 'let', 'loose', 'heavy', 'artillery', 'charge', 'samurai', 'pretty', 'lame', 'way', 'gets', 'hit', 'time', 'minor', 'recoverable', 'wound', 'good', 'relation', 'warrior', 'get', 'riddle', 'lethal', 'hit', 'end', 'rant', 'end', 'spoiler', 'regardless', 'couple', 'fault', 'beautifully', 'shoot', 'emotionally', 'invest', 'incredibly', 'detailed', 'movie', 'year', 'reviewers', 'note', 'star', 'allow', 'star', 'deduction', 'ending', 'edited', 'correct', 'mistake', 'rant', 'viewing', 'plot', 'detail', 'opinion', 'reveal', 'major', 'detail', 'movie', 'plot', 'wish', 'see', 'movie', 'wish', 'roger', 'ebert', 'give', 'star', 'say', 'rare', 'christmas', 'comedy', 'heart', 'brain', 'wicked', 'sense', 'humor', 'charm', 'sock', 'right', 'mantelpiece', 'roger', 'movie', 'think', 'walk', 'theater', 'feeling', 'like', 'waste', 'minute', 'time', 'go',  ...
# PHONES ['kind', 'disappointed', 'expensive', 'phone', 'system', 'siemen', 'phone', 'system', 'sound', 'start', 'degrade', 'year', 'switch', 'expensive', 'panasonic', 'system', 'phone', 'nice', 'feeling', 'like', 'choose', 'line', 'want', 'dial', 'feature', 'miss', 'siemens', 'phone', 'illuminated', 'keypad', 'work', 'volume', 'control', 'easy', 'use', 'talk', 'wish', 'go', 'bit', 'louder', 'volume', 'directory', 'connect', 'caller', 'id', 'like', 'cell', 'phone', 'siemens', 'phone', 'mean', 'exist', 'directory', 'phone', 'number', 'want', 'directory', 'display', 'instead', 'default', 'caller', 'id', 'caller', 'id', 'unknown', 'like', 'time', 'cell', 'phone', 'good', 'transfering', 'difficult', 'phone', 'yell', 'house', 'pick', 'phone', 'transfer', 'easy', 'ask', 'number', 'extension', 'hold', 'label', 'extension', 'number', 'like', 'fact', 'phone', 'act', 'like', 'stand', 'phone', 'system', 'act', 'like', 'system', 'share', 'directory', 'big', 'minus', 'type', 'directory', 'phone', 'number', 'name', 'system', 'phone', 'clear', 'received', 'calls', 'label', 'system', 'point', 'buy', 'system', 'phone', 'share', 'mute', 'button', 'base', 'handset', 'speakerphone', 'work', 'central', 'air', 'instal', 'house', 'blower', 'interfere', 'sound', 'quality', 'handset', 'get', 'foot', 'upside', 'use', 'general', 'mailbox', 'work', 'access', 'road', 'multiple', 'mailbox', 'use', 'general', 'box', 'phone', 'use', 'nimh', 'battery', 'good', 'big', 'fan', 'panasonic', 'product', 'design', 'build', 'probably', 'kx', 'm', 'ghz', 'phone', 'system', 'disappointment', 'problem', 'sound', 'quality', 'memory', 'chip', 'inexpensive', 'panasonic', 'save', 'money', 'put', 'small', 'memory', 'chip', 'system', 'compression', 'technology', 'utilize', 'fit', 'minute', 'record', 'message', 'chip', 'tell', 'sound', 'quality', 'awful', 'ironically', 'good', 'sound', 'quality', 'come', 'old', 'analog', 'answer', 'machine', 'use', 'cassette', 'tape', 'technological', 'advance', 'second', 'problem', 'power', 'pack', 'consist', 'cheap', 'nicd', 'aa', 'battery', 'encase', 'plastic', 'worse', 'low', 'capacity', 'nicds', 'mah', 'nicd', 'old', 'technology', 'rechargeable', 'battery', 'cadmium', 'nasty', 'environmental', 'toxin', 'nicd', 'battery', 'drain', 'quickly', 'use', 'memory', 'effect', 'drain', 'power', 'completely', 'recharge', 'charge', 'current', 'level', 'charge', 'phone', 'handset', 'work', 'hour', 'recharge', 'need', 'store', 'charger', 'base', 'significantly', 'reduce', 'life', 'battery', 'panasonic', 'opt', 'current', 'technology', 'mah', 'nmh', 'nickel', 'metal', 'hydride', 'battery', 'hr', 'usage', 'time', 'boost', 'hrs', 'memory', 'effect', 'cost', 'cutting', 'panasonic', 'go', 'charge', 'people', 'product', 'build', 'quality', 'component', 'problem', 'endure', 'goofy', 'voice', 'tell', 'thing', 'efficiently', 'convey', 'visual', 'indicator', 'suppose', 'electronic', 'voice', 'panasonic', 'way', 'add', 'gee', 'wow', 'factor', 'example', 'new', 'technology', 'make', 'life', 'efficient', 'old', 'answering', 'machine', 'lcd', 'display', 'tell', 'new', 'message', 'machine', 'tiny', 'red', 'light', 'screen', 'message', 'erase', 'idea', 'message', 'add', 'start', 'push', 'button', 'waste', 'time', 'press', 'button', 'listen', 'voice', 'time', 'press', 'extra', 'button', 'like', 'mailbox', 'time', 'use', 'message', 'mailbox', 'password', 'protect', 'message', 'storage', 'user', 'system', 'gripe', 'antenna', 'base', 'unit', 'inch', 'high', 'way', 'hear', 'voice', 'handset', 'phone', 'take', 'handset', 'fairly', 'bulky', 'heavy', 'plus', 'range', 'ghz', 'phone', 'fairly', 'good', 'quality', 'degrade', 'distance', 'worry', 'zap', 'brain', 'high', 'energy', 'radio', 'signal', 'go', 'cordless', 'nice', 'wish', 'list', 'addition', 'fix', 'mention', 'gripe', 'great', 'way', 'speed', 'boring', 'message', 'old', 'digital', 'answering', 'machine', 'allow', 'increase', 'talk', 'speed', 'addition', 'jump', 'second', 'interval', 'slow', 'record', 'message', 'change',  ...
# HOTELS ['disney', 'beach', 'club', 'resort', 'truly', 'beautiful', 'relaxing', 'perfectly', 'situated', 'connect', 'yacht', 'club', 'resort', 'new', 'england', 'sailing', 'theme', 'beach', 'club', 'theme', 'like', 'seaside', 'retreat', 'decorate', 'pale', 'refreshing', 'beachy', 'color', 'pool', 'call', 'stormalong', 'bay', 'share', 'resort', 'beach', 'club', 'jewel', 'element', 'keep', 'family', 'come', 'huge', 'lot', 'nook', 'cranny', 'bridge', 'sand', 'cover', 'instead', 'typical', 'concrete', 'big', 'water', 'slide', 'stand', 'set', 'beach', 'hair', 'bead', 'braid', 'buy', 'seashell', 'jewelry', 'water', 'sprite', 'small', 'speed', 'boat', 'available', 'rental', 'spend', 'day', 'hang', 'sister', 'resort', 'run', 'thing', 'dining', 'directly', 'yacht', 'beach', 'club', 'boardwalk', 'resort', 'minute', 'walk', 'away', 'ton', 'dining', 'entertainment', 'option', 'boardwalk', 'look', 'beautiful', 'light', 'night', 'get', 'lagoon', 'view', 'room', 'dining', 'choice', 'yacht', 'beach', 'club', 'shabby', 'cape', 'cafe', 'offer', 'character', 'buffet', 'breakfast', 'morning', 'non', 'character', 'delicious', 'clambake', 'buffet', 'night', 'menu', 'item', 'clam', 'chowder', 'fresh', 'clam', 'corn', 'cob', 'new', 'potato', 'chicken', 'rice', 'salad', 'bar', 'scrumptious', 'dessert', 'bar', 'wdw', 'mention', 'kid', 'section', 'fry', 'shrimp', 'chicken', 'tender', 'etc', 'hurricane', 'hannah', 'snack', 'bar', 'pool', 'find', 'burger', 'tuna', 'sandwich', 'etc', 'drink', 'alcoholic', 'non', 'eat', 'patio', 'poolside', 'chair', 'yacht', 'club', 'want', 'good', 'steak', 'life', 'yachtsman', 'steakhouse', 'absolutely', 'sure', 'stop', 'beaches', 'cream', 'fifty', 'style', 'soda', 'fountain', 'good', 'cheeseburger', 'fry', 'wdw', 'plus', 'hard', 'ice', 'cream', 'sort', 'ice', 'cream', 'concoction', 'love', 'chocolate', 'malted', 'brownie', 'sundaes', 'yum', 'stop', 'stay', 'resort', 'thank', 'later', 'hour', 'room', 'service', 'menu', 'available', 'accommodations', 'guest', 'room', 'spacious', 'comfortable', 'queen', 'sized', 'bed', 'large', 'bathroom', 'outside', 'sink', 'table', 'chair', 'couch', 'serve', 'bed', 'tv', 'mini', 'bar', 'room', 'housekeeping', 'great', 'job', 'keep', 'room', 'beautiful', 'room', 'balcony', 'upper', 'floor', 'room', 'tiny', 'balcony', 'barely', 'hold', 'people', 'stand', 'upright', 'want', 'balcony', 'chair', 'definitely', 'request', 'make', 'reservation', 'fax', 'phone', 'day', 'check', 'like', 'little', 'space', 'money', 'want', 'request', 'hammerhead', 'corner', 'room', 'spacious', 'spread', 'beach', 'club', 'room', 'complaint', 'little', 'storage', 'space', 'clothe', 'large', 'drawer', 'stand', 'chest', 'small', 'drawer', 'closet', 'space', 'hanger', 'transportation', 'transportation', 'pretty', 'darn', 'good', 'non', 'monorail', 'resort', 'minute', 'boat', 'launch', 'disney', 'studios', 'bus', 'service', 'magic', 'kingdom', 'animal', 'kingdom', 'scenic', 'walk', 'epcot', 'center', 'enter', 'world', 'showcase', 'minute', 'walk', 'bonus', 'france', 'certain', 'spot', 'resort', 'boat', 'launch', 'epcot', 'note', 'happen', 'car', 'rental', 'car', 'property', 'make', 'sense', 'drive', 'monorail', 'resort', 'grand', 'floridian', 'contemporary', 'polynesian', 'park', 'monorail', 'magic', 'kingdom', 'likewise', 'animal', 'kingdom', 'park', 'new', 'animal', 'kingdom', 'lodge', 'simply', 'drive', 'park', 'save', 'lot', 'time', 'spend', 'uncomfortable', 'bus', 'overall', 'disney', 'beach', 'club', 'know', 'good', 'time', 'family', 'stay', 'yacht', 'beach', 'club', 'option', 'step', 'away', 'highly', 'recommend', 'resort', 'know', 'ritz', 'carlton', 'know', 'feel', 'special', 'day', 'celebration', 'people', 'age', 'tea', 'room', 'enjoy', 'afternoon', 'friend', 'family', 'special', 'occasion', 'father', 'friend', 'celebrate', 'birthday', 'thing', 'strike', 'staff', 'clientele', 'feel', 'absolutely', 'regal', 'father', 'tell', 'tell', 'meet', 'sofa', 'corner', 'sound', 'cryptic', 'soon', 'tell', 'hostess', 'nod', 'kno ...
# COMPUTERS ['thing', 'notice', 'huge', 'screen', 'inch', 'probably', 'big', 'portable', 'past', 'size', 'screen', 'find', 'fairly', 'potent', 'laptop', 'laptop', 'loosely', 'spec', 'desktop', 'pentium', 'hyper', 'threading', 'ghz', 'screen', 'inch', 'weight', 'lbs', 'storage', 'gig', 'hard', 'drive', 'dvd', 'dvd', 'r', 'rw', 'yes', 'write', 'dvd', 'internet', 'ethernet', 'integrated', 'wireless', 'adapter', 'connectivity', 'port', 'iee', 'port', 'ram', 'mb', 'video', 'geforcego', 'mg', 'vram', 'battery', 'life', 'hour', 'roughly', 'heavy', 'use', 'operate', 'system', 'windows', 'xp', 'impression', 'extra', 'wide', 'screen', 'size', 'ability', 'burn', 'dvd', 'lend', 'laptop', 'consider', 'extremely', 'good', 'movable', 'movie', 'theater', 'good', 'sound', 'stereo', 'harmon', 'karmon', 'speaker', 'screen', 'pretty', 'clear', 'crisp', 'movie', 'picture', 'pretty', 'good', 'good', 'hdtv', 'bad', 'pretty', 'big', 'movie', 'buff', 'ability', 'watch', 'favorite', 'movie', 'big', 'factor', 'plus', 'extra', 'wide', 'screen', 'format', 'lend', 'perfectly', 'movie', 'preloaded', 'program', 'make', 'versatile', 'find', 'quicken', 'program', 'useful', 'balance', 'finance', 'especially', 'like', 'integrate', 'wireless', 'modem', 'wireless', 'network', 'home', 'connect', 'internet', 'easy', 'require', 'lot', 'tinkering', 'lot', 'web', 'page', 'extra', 'wide', 'format', 'waste', 'space', 'screen', 'play', 'game', 'machine', 'great', 'high', 'spec', 'machine', 'allow', 'play', 'game', 'like', 'freelancer', 'good', 'frame', 'rate', 'game', 'actually', 'wide', 'format', 'game', 'regular', 'laptop', 'buy', 'external', 'mouse', 'touch', 'pad', 'game', 'try', 'graphic', 'intensive', 'game', 'come', 'let', 'know', 'able', 'find', 'program', 'use', 'hyper', 'thread', 'aspect', 'cpu', 'impression', 'drawback', 'consider', 'laptop', 'think', 'movable', 'movie', 'theater', 'lbs', 'pretty', 'heavy', 'thing', 'lug', 'plus', 'extra', 'wide', 'screen', 'fit', 'average', 'laptop', 'bag', 'size', 'laptop', 'make', 'hard', 'place', 'place', 'probably', 'movie', 'room', 'room', 'house', 'house', 'recommend', 'lap', 'option', 'laptop', 'require', 'desk', 'want', 'bring', 'laptop', 'find', 'hard', 'find', 'bag', 'fit', 'inch', 'screen', 'find', 'barely', 'fit', 'require', 'squeezing', 'line', 'great', 'movie', 'great', 'lap', 'personaly', 'monster', 'work', 'day', 'non', 'linear', 'video', 'editor', 'new', 'professional', 'paper', 'weight', 'art', 'department', 'sure', 'nice', 'theory', 'mb', 'ram', 'expandable', 'gb', 'build', 'dvd', 'burner', 'build', 'zip', 'drive', 'airport', 'usb', 'pretty', 'blue', 'clear', 'case', 'fun', 'end', 'm', 'afraid', 'mac', 'os', 'come', 'nightmare', 'opinion', 'title', 'explanation', 'new', 'macintosh', 'exactly', 'mhz', 'paper', 'weight', 'art', 'director', 'disgust', 'crashing', 'lock', 'finder', 'dissapearing', 'dvd', 'drive', 'burn', 'right', 'computer', 'look', 'nice', 'outside', 'want', 'real', 'laugh', 'hold', 'dvd', 'flip', 'door', 'open', 'look', 'cover', 'headphone', 'output', 'volume', 'wheel', 'internal', 'dvd', 'exactly', 'retool', 'oh', 'yes', 'apple', 'cut', 'those', 'corner', 'accountant', 'excellent', 'job', 'sure', 'year', 'end', 'bonus', 'big', 'fast', 'machine', 'run', 'fast', 'crash', 'overall', 'opinion', 'machine', 'great', 'potential', 'unusable', 'box', 'purchase', 'product', 'like', 'think', 'different', 'sick', 'originally', 'go', 'ibook', 'feature', 'ibook', 'pale', 'comparison', 'imac', 'go', 'compusa', 'buy', 'blueberry', 'big', 'mistake', 'get', 'computer', 'home', 'think', 'great', 'see', 'little', 'black', 'dot', 'screen', 'hear', 'dead', 'pixel', 'lcd', 'display', 'kind', 'use', 'laptop', 'like', 'powerbook', 'series', 'take', 'day', 'give', 'new', 'day', 'test', 'new', 'fine', 'test', 'dvd', 'movie', 'window', 'dvd', 'play', 'big', 'line', 'go', 'horizontally', 'size', 'scroll', 'bar', 'take', 'compusa', 'say', 'wait', 'day', 'refund', 'mail', 'opt', 'refund', 'believe', 'strike', 'philosophy', ' ...
# CARS ['attract', 'mirage', 'coupe', 'short', 'slender', 'female', 'car', 'dream', 'seat', 'envelop', 'comfortably', 'far', 'lancer', 'long', 'road', 'trip', 'seat', 'entirely', 'different', 'story', 'rigid', 'firm', 'little', 'leg', 'room', 'year', 'old', 'constantly', 'complain', 'year', 'car', 'perform', 'electronic', 'work', 'engine', 'strong', 'etc', 'year', 'mark', 'hit', 'little', 'thing', 'start', 'happen', 'driver', 'window', 'slide', 'initial', 'ker', 'klunk', 'bulb', 'begin', 'blow', 'light', 'quit', 'work', 'fuse', 'engine', 'spite', 'professional', 'maintenance', 'begin', 'sound', 'ill', 'know', 'well', 'alternative', 'class', 'suggest', 'save', 'money', 'want', 'vehicle', 'problem', 'long', 'notorious', 'year', 'mark', 'want', 'buy', 'car', 'extra', 'k', 'buy', 'car', 'bad', 'handling', 'characteristic', 'accord', 'memory', 'heated', 'seat', 'xenon', 'headlamp', 'piece', 'plastic', 'wood', 'offer', 'expensive', 'accord', 'engine', 'ultra', 'responsive', 'engine', 'enhance', 'engine', 'acura', 'liberally', 'borrow', 'host', 'technology', 'nsx', 'honda', 'racing', 'design', 'pool', 'show', 'acceleration', 'strong', 'linear', 'beat', 'audi', 'tiptronic', 'hang', 'provide', 'orgasmic', 'acceleration', 'reach', 'cruise', 'shift', 'hesitant', 'performance', 'like', 'lofty', 'cruiser', 'problem', 'thank', 'god', 'sportshift', 'mode', 'allow', 'thing', 'engine', 'truly', 'superb', 'body', 'terrible', 'shame', 'hp', 'powerhouse', 'suit', 'chassis', 'big', 'mismatch', 'drive', 'present', 'form', 'make', 'chassis', 'beg', 'mercy', 'drive', 'hp', 'accord', 'immense', 'power', 'mate', 'wheel', 'drive', 'create', 'lot', 'torque', 'steer', 'acura', 'claim', 'eliminate', 'press', 'hype', 'tire', 'wheel', 'poorly', 'select', 'kind', 'power', 'make', 'vehicle', 'difficult', 'steer', 'rough', 'pavement', 'high', 'speed', 'vsa', 'system', 'work', 'test', 'time', 'racetrack', 'car', 'exhibit', 'skid', 'car', 'drive', 'exactly', 'mile', 'rattle', 'like', 'old', 'clunker', 'people', 'think', 'make', 'sport', 'car', 'hell', 'handling', 'characteristic', 'car', 'prime', 'importance', 'car', 'qualify', 'sport', 'car', 'sedan', 'moniker', 'sorry', 'build', 'quality', 'substandard', 'large', 'gap', 'body', 'especially', 'near', 'door', 'know', 'design', 'look', 'terrible', 'ergonomic', 'average', 'excellent', 'able', 'fit', 'drink', 'handr', 'shifter', 'get', 'way', 'poorly', 'design', 'sunroof', 'switch', 'hide', 'dash', 'instead', 'sunroof', 'time', 'want', 'plant', 'trunk', 'rear', 'seatback', 'bolt', 'fold', 'long', 'accord', 'interior', 'room', 'wierd', 'design', 'cue', 'car', 'redeem', 'quality', 'complete', 'waste', 'money', 'buy', 'accord', 'save', 'extra', 'buck', 'want', 'real', 'fun', 'drive', 'sport', 'sedan', 'spend', 'extra', 'buy', 'bmw', 'series', 'fully', 'load', 'pre', 'own', 'series', 'low', 'mile', 'price', 'range', 'series', 'expensive', 'reason', 'good', 'thing', 'cost', 'money', 'good', 'safety', 'class', 'handle', 'like', 'rail', 'drop', 'dead', 'gorgeous', 'styling', 'alternative', 'expensive', 'audi', 'test', 'drive', 'want', 'touch', 'tl', 'foot', 'barge', 'pole', 'truly', 'exhillarate', 'currently', 'sell', 'sticker', 'obviously', 'line', 'update', 'acura', 'offer', 'higher', 'price', 'pure', 'performance', 'orient', 'version', 'model', 'drive', 'enthusiast', 'awd', 'tire', 'comfortable', 'seat', 'compensate', 'stiff', 'suspension', 'improve', 'braking', 'real', 'wood', 'trim', 'speed', 'manual', 'reduce', 'length', 'maintain', 'interior', 'room', 'improve', 'sedate', 'styling', 'attract', 'lot', 'attention', 'seriously', 'compete', 'bonafide', 'sport', 'car', 'like', 'audi', 'know', 'trouble', 'drive', 'certain', 'car', 'day', 'find', 'desperately', 'look', 'like', 'car', 'gear', 'shifter', 'look', 'cool', 'reasoning', 'begin', 'alas', 'mean', 'mercury', 'cougar', 'simply', 'great', 'car', 'trouble', 'cougar', 'perfectly', 'fine', 'car', 'judge', 'merit', 'adequate', 'power', 'distinct', 'styling', 'plenty', 'opt ...

# %%
listaParaCluster=[]
documents.clear()
for etiqueta in mapaProcesado:
  cadenaDeTerminos = ' '.join(mapaProcesado[etiqueta])  # Convertimos la lista de tokens en una sola cadena de palabras para poder alimentar el vectorizer
  listaParaCluster.append(cadenaDeTerminos)

for elemento in listaParaCluster:
  print(elemento)
# Out:
# plot detail opinion reveal major detail movie plot rest word good movie perfect film see succeed level set attain review know story cruise civil war hero drown sin liquor chance atrocity see native americans gets hire train new western style army emperor japan gets capture fail attempt defeat samurai rebellion movie honestly look forward movie year force reluctant wife interest leave theatre happily surprised high expectation disappoint story fictional disregard historically correct complaint read director say upfront try extremely accurate thing era story true yes predictable moment distract enjoy epic tale costumes win oscar far exquiste creation see year course talk samurai armor foremost cruise promotional material good see act wise cruise stay game think oscar worthy despite training role well favorite performance jerry maguire minority report interview vampire movie fall right line perform good character transition torture past appreciation earnest learning samurai way support character good ken watanabe nominate deliver wide range warrior strength father compassion plenty masterfully craft physical special effect visual effect honestly yes certainly conceive feel see action look entirely real natural long time blow away intense battle scene samurai gear fighting ninjas yes lethal imagine see samurai sword wield amazing skill film choreography fight especially opening attack ninja raid breathtake actually cool grisly death leave feel bit uneasy mean kill person utterly horrible war devestation leave completely de sensitized forget mention gorgeous cinematagraphy score new beautiful venue new zealand truly believe look ancient japan movie witness jaw drop landscape big fan hans zimmer black hawk gladiator score job blend grand eclectic new endeavor soundtrack purchase time awhile actually experience music film film main theme spirit gladiator mohicans obviously far east influence lush rich emotionally charge piece music caveat ending lose movie momentum feel wishy washy rush clear possible lose end story writer know properly close stamp typ
side jazz hood scoop rear spoiler inch alloy fog light actually lot stuff pack little car consider price xr cougar come special logo door pillar floor mat come soon anniversary edition guess appearance package cougar strong point mainly stand exterior styling interior match mercury cougar good look sporty coupe edgy styling gets notice crowd certainly styling subjective cougar proof feel cougar definition ugly perspective admit different look note ford cougar half bad look car loose fake hood scoop fast modern car lure rakish good look outside fall short inside car cougar edgy styling theme continue inside cougar metallic look surface racy gauge aftermarket style pedal chrome accent door sill sport seat body color insert bucket rear s ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(listaParaCluster)

# %%
X
# Out:
# <8x12802 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26600 stored elements in Compressed Sparse Row format>

# %%
k = 8
model = KMeans(n_clusters=k)
model.fit(X) # entrenamiento
# Out:
# KMeans()

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()
for i in range(k):
  print("\nCluster:", i)
  for ind in order_centroids[i, :10]:
    print(' \t', terms[ind])
# Out:
# Top terms per cluster:
#
# Cluster: 0
#  	 book
#  	 novel
#  	 grisham
#  	 read
#  	 luke
#  	 story
#  	 stephanie
#  	 character
#  	 plot
#  	 cotton
#
# Cluster: 1
#  	 pan
#  	 cookware
#  	 stainless
#  	 pot
#  	 clothe
#  	 cook
#  	 lid
#  	 steel
#  	 dishwasher
#  	 set
#
# Cluster: 2
#  	 dell
#  	 imac
#  	 computer
#  	 apple
#  	 pc
#  	 mac
#  	 software
#  	 mb
#  	 keyboard
#  	 laptop
#
# Cluster: 3
#  	 hotel
#  	 room
#  	 resort
#  	 disney
#  	 pool
#  	 stay
#  	 beach
#  	 restaurant
#  	 time
#  	 service
#
# Cluster: 4
#  	 album
#  	 lyric
#  	 track
#  	 rap
#  	 song
#  	 beat
#  	 hip
#  	 like
#  	 hop
#  	 rapper
#
# Cluster: 5
#  	 phone
#  	 handset
#  	 panasonic
#  	 cordless
#  	 caller
#  	 battery
#  	 system
#  	 id
#  	 button
#  	 feature
#
# Cluster: 6
#  	 car
#  	 seat
#  	 engine
#  	 ford
#  	 drive
#  	 like
#  	 rear
#  	 taurus
#  	 look
#  	 xterra
#
# Cluster: 7
#  	 movie
#  	 film
#  	 plot
#  	 santa
#  	 elf
#  	 like
#  	 character
#  	 samurai
#  	 seuss
#  	 cat

# %% [markdown]
# My accommodation is near the river and the mountain.
# I have John Lennon's CD at home.
# The most interesting sections are the last ones.
# I enjoyed with the last essay of Pinker.
# The steering of the car is very hard.

# %%
frases = ["My accommodation is near the river and the mountain.","I have John Lennon's CD at home.","The most interesting sections are the last ones.","I enjoyed with the last essay of Pinker.","The steering of the car is very hard."]
for texto in frases:
    Y = vectorizer.transform([texto])
    prediction = model.predict(Y)
    print('Texto:', texto)
    print('Cluster donde encajaría:', prediction)
# Out:
# Texto: My accommodation is near the river and the mountain.
# Cluster donde encajaría: [3]
# Texto: I have John Lennon's CD at home.
# Cluster donde encajaría: [2]
# Texto: The most interesting sections are the last ones.
# Cluster donde encajaría: [0]
# Texto: I enjoyed with the last essay of Pinker.
# Cluster donde encajaría: [3]
# Texto: The steering of the car is very hard.
# Cluster donde encajaría: [6]
