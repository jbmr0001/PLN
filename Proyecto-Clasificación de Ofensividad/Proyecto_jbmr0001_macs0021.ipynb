# %% [markdown]
# Proyecto: Deteccón de lenguaje ofensivo
#
# Autores de la práctica: Juan Bautista Muñoz Ruiz jbmr0001@red.ujaen.es Marco Antonio Carrión Soriano macs0021@red.ujaen.es

# %% [markdown]
# ### Prueba de nltk y algoritmo de prueba de vectorizadores y modelos

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import pandas as pd
from itertools import product
from google.colab import drive

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from gensim.models import Word2Vec


# Montar Google Drive
drive.mount('/content/drive')

# Descargar stopwords en español
nltk.download('stopwords')
stop_words = set(stopwords.words('spanish'))

# Ruta de los archivos en Google Drive
train_path = '/content/drive/MyDrive/PLN/Proyecto/train.tsv'
dev_path = '/content/drive/MyDrive/PLN/Proyecto/dev.tsv'

# Cargar los datos de entrenamiento desde el archivo train.tsv
train_data = pd.read_csv(train_path, sep='\t', encoding='latin1')

# Obtener los comentarios y las etiquetas de entrenamiento
train_comments = train_data['comment'].tolist()
train_labels = train_data['label'].tolist()

# Preprocesar los comentarios de entrenamiento
def preprocess_text(comment):
    tokens = word_tokenize(comment.lower())
    filtered_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    preprocessed_text = ' '.join(filtered_tokens)
    return preprocessed_text

preprocessed_train_comments = [preprocess_text(comment) for comment in train_comments]

print("\nPRIMER COMENTARIO PROCESADO: ", preprocessed_train_comments[0],"\n")
print("\nPRIMERA ETIQUETA: ", train_labels[0],"\n")

# Cargar los datos de prueba desde el archivo dev.tsv
dev_data = pd.read_csv(dev_path, sep='\t')

# Obtener los comentarios y las etiquetas de prueba
dev_comments = dev_data['comment'].tolist()
dev_labels = dev_data['feature'].tolist()

# Preprocesar los comentarios de prueba
preprocessed_dev_comments = [preprocess_text(comment) for comment in dev_comments]

print("\nPRIMER COMENTARIO DEV: ", preprocessed_dev_comments[0],"\n")
print("\nPRIMERA ETIQUETA DEV: ", dev_labels[0],"\n")

# Definir los métodos y vectorizadores a probar
methods = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'SVM': SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(random_state=62),
    'Naive Bayes': GaussianNB(),
    # Agrega más métodos aquí
}

vectorizers = {
    'CountVectorizer': CountVectorizer(),
    'TfidfVectorizer': TfidfVectorizer(),
    # Agrega más vectorizadores aquí
}

# Entrenar y evaluar los modelos para cada combinación de método y vectorizador
resultados = []
for (method_name, method_model), (vectorizer_name, vectorizer_model) in product(methods.items(), vectorizers.items()):
    # Crear el vectorizador y transformar los comentarios de entrenamiento
    X_train = vectorizer_model.fit_transform(preprocessed_train_comments)

    # Entrenar el modelo con los datos de entrenamiento
    method_model.fit(X_train, train_labels)

    # Transformar los comentarios de prueba utilizando el vectorizador
    X_dev = vectorizer_model.transform(preprocessed_dev_comments)

    # Predecir las etiquetas de prueba utilizando el modelo entrenado
    y_pred = method_model.predict(X_dev)

    # Obtener el informe de clasificación para evaluar el modelo
    report = classification_report(dev_labels, y_pred, output_dict=True)
    resultados.append((method_name, vectorizer_name, report))
    print("Método: ", method_name, " Vectorizador: ", vectorizer_name, " === ", report)
# Out:
# '# Montar Google Drive\ndrive.mount(\'/content/drive\')\n\n# Descargar stopwords en español\nnltk.download(\'stopwords\')\nstop_words = set(stopwords.words(\'spanish\'))\n\n# Ruta de los archivos en Google Drive\ntrain_path = \'/content/drive/MyDrive/PLN/Proyecto/train.tsv\'\ndev_path = \'/content/drive/MyDrive/PLN/Proyecto/dev.tsv\'\n\n# Cargar los datos de entrenamiento desde el archivo train.tsv\ntrain_data = pd.read_csv(train_path, sep=\'\t\', encoding=\'latin1\')\n\n# Obtener los comentarios y las etiquetas de entrenamiento\ntrain_comments = train_data[\'comment\'].tolist()\ntrain_labels = train_data[\'label\'].tolist()\n\n# Preprocesar los comentarios de entrenamiento\ndef preprocess_text(comment):\n    tokens = word_tokenize(comment.lower())\n    filtered_tokens = [token for token in tokens if token.isalpha() and token not in stop_words]\n    preprocessed_text = \' \'.join(filtered_tokens)\n    return preprocessed_text\n\npreprocessed_train_comments = [preprocess_text(comment) for comment in train_comments]\n\nprint("\nPRIMER COMENTARIO PROCESADO: ", preprocessed_train_comments[0],"\n")\nprint("\nPRIMERA ETIQUETA: ", train_labels[0],"\n")\n\n# Cargar los datos de prueba desde el archivo dev.tsv\ndev_data = pd.read_csv(dev_path, sep=\'\t\')\n\n# Obtener los comentarios y las etiquetas de prueba\ndev_comments = dev_data[\'comment\'].tolist()\ndev_labels = dev_data[\'feature\'].tolist()\n\n# Preprocesar los comentarios de prueba\npreprocessed_dev_comments = [preprocess_text(comment) for comment in dev_comments]\n\nprint("\nPRIMER COMENTARIO DEV: ", preprocessed_dev_comments[0],"\n")\nprint("\nPRIMERA ETIQUETA DEV: ", dev_labels[0],"\n")\n\n# Definir los métodos y vectorizadores a probar\nmethods = {\n    \'Logistic Regression\': LogisticRegression(max_iter=1000),\n    \'SVM\': SVC(),\n    \'K-Nearest Neighbors\': KNeighborsClassifier(),\n    \'Decision Tree\': DecisionTreeClassifier(random_state=62),\n    \'Naive Bayes\': GaussianNB(),\n    # Agrega más métodos aquí\n}\n\nvectorizers = {\n    \'CountVectorizer\': CountVectorizer(),\n    \'TfidfVectorizer\': TfidfVectorizer(),\n    # Agrega más vectorizadores aquí\n}\n\n# Entrenar y evaluar los modelos para cada combinación de método y vectorizador\nresultados = []\nfor (method_name, method_model), (vectorizer_name, vectorizer_model) in product(methods.items(), vectorizers.items()):\n    # Crear el vectorizador y transformar los comentarios de entrenamiento\n    X_train = vectorizer_model.fit_transform(preprocessed_train_comments)\n\n    # Entrenar el modelo con los datos de entrenamiento\n    method_model.fit(X_train, train_labels)\n\n    # Transformar los comentarios de prueba utilizando el vectorizador\n    X_dev = vectorizer_model.transform(preprocessed_dev_comments)\n\n    # Predecir las etiquetas de prueba utilizando el modelo entrenado\n    y_pred = method_model.predict(X_dev)\n\n    # Obtener el informe de clasificación para evaluar el modelo\n    report = classification_report(dev_labels, y_pred, output_dict=True)\n    resultados.append((method_name, vectorizer_name, report))\n    print("Método: ", method_name, " Vectorizador: ", vectorizer_name, " === ", report)'

# %% [markdown]
# ### Resolución del problema

# %%
import spacy.cli
spacy.cli.download("es_core_news_sm")

# %%
import es_core_news_sm
nlp = es_core_news_sm.load()

# %%
from google.colab import drive  #Montamos el drive
drive.mount('/content/drive')

# %%
import os #Abrimos la carpeta
path = os.chdir("/content/drive/MyDrive/PLN/Proyecto")
os.getcwd()

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
def getCodificacion(texto): #Función para calcular el encoding con la libreria chardet
  import chardet

  with open(texto, 'rb') as f:
    resultado = chardet.detect(f.read())

  return resultado['encoding']

# %%
#Cargando lexicon
def tokenizar(texto):  
    texto=nlp(texto)
    tokens=[]
    textoProcesado=""
    for token in texto:
        if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
            tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula
    textoProcesado=" ".join(tokens)
    #print(texto,"-",textoProcesado,end="\n")
    return textoProcesado

elementosLexicon=[]
etiquetasLexicon=[]
with open('Lexicón.txt', 'r') as archivo:
    for linea in archivo.readlines():
      etiquetasLexicon.append("OFF")
      elementosLexicon.append(tokenizar(linea))
      #elementosLexicon.append(linea)

# %% [markdown]
# ### Procesado quitando palabras ofensivas de textos no ofensivos

# %%
'''def preprocesarLista(lista): #Función para quitar comillas y corchetes
    listaAux=[]
    for elemento in lista:
        listaAux.append(elemento.replace("'","").replace("]","").replace("[",""))
    return listaAux

def tokenizarTexto(lista,filename):
   
    print(filename)
    texto=nlp(lista[1])
    tokens=[]
    textoProcesado=""
    for token in texto:
        if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
          
          #############################QUITAMOS DE textos NON los insultos############################

            if lista[2]=="NON" and filename=="train.tsv":
              if token.lemma_.lower() not in elementosLexicon:
                tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula
              else:
                print("------Quitada de texto NON:",token.lemma_.lower(),filename)
            else:
              tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula

          #############################QUITAMOS DE textos NON los insultos############################

    textoProcesado=" ".join(tokens)
    return textoProcesado

########################CARGA DE DATOS##########################
import re
import os 
import glob   #Lectura y procesado de los archivos
import chardet
import openpyxl
import csv
import pandas as pd
path = os.chdir("/content/drive/MyDrive/PLN/Proyecto")
os.getcwd()

mapaLineas={}
comentarios_training = []
comentarios_dev = []
for filename in glob.glob('*.tsv'):  #Lectura de todos los archivos xlsx
    print(filename)
    if filename!="test.tsv":
      with open(filename,encoding='utf-8',errors='ignore') as file:
        tsv_file = csv.reader(file, delimiter="\t", quotechar='"')
        with open(filename+".txt", 'w') as f:
            totales=0
            for line in tsv_file:
                listaProcesada=line
                print("Procesando ",filename," id ",listaProcesada[0],"Totales:",totales)
                totales=totales+1

                if len(listaProcesada) == 5 and (listaProcesada[2] == 'OFF' or listaProcesada[2] == 'NON'):
                    listaProcesada[1]=tokenizarTexto(listaProcesada,filename)
                    mapaLineas[filename]=listaProcesada
                    comentario = {
                        'id': listaProcesada[0],
                        'texto': listaProcesada[1],
                        'ofensividad': listaProcesada[2],
                        'genero': listaProcesada[3],
                        'plataforma': listaProcesada[4]
                    }

                    if(filename=="train.tsv"):
                      comentarios_training.append(comentario)
                    else:
                      comentarios_dev.append(comentario)
                    f.write(listaProcesada[0])
                    f.write("\n")
                    f.write(listaProcesada[1])
                    f.write("\n")
                    f.write(listaProcesada[2])
                    f.write("\n")
                    f.write(listaProcesada[3])
                    f.write("\n")
                    f.write(listaProcesada[4])
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                else:
                    print("Error: La línea no tiene la longitud esperada.")'''

# %% [markdown]
# ### Procesado con emojis

# %%
'''!pip install emoji
import emoji
def preprocesarLista(lista): #Función para quitar comillas y corchetes
    listaAux=[]
    for elemento in lista:
        listaAux.append(elemento.replace("'","").replace("]","").replace("[",""))
    return listaAux

def tokenizarTexto(lista):
     ####################################Emojis##################
  
    emojis=[]
    for palabra in lista[1]:
      if emoji.is_emoji(palabra):
        emojis.append(emoji.demojize(palabra)) #lo pasamos a texto para que lo lea el modelo
        #print(emoji.demojize(palabra))
     ####################################Emojis##################

    texto=nlp(lista[1])
    tokens=[]
    textoProcesado=""
    for token in texto:
        if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
            tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula
     
    ####################################Emojis##################
    for emo in emojis:
      #print(emoji)
      tokens.append(emo)
    ####################################Emojis##################

    textoProcesado=" ".join(tokens)
    print(textoProcesado)
    return textoProcesado

########################CARGA DE DATOS##########################
import re
import os 
import glob   #Lectura y procesado de los archivos
import chardet
import openpyxl
import csv
import pandas as pd
path = os.chdir("/content/drive/MyDrive/PLN/Proyecto")
os.getcwd()

mapaLineas={}
comentarios_training = []
comentarios_dev = []
for filename in glob.glob('*.tsv'):  #Lectura de todos los archivos xlsx
    print(filename)
    if filename!="test.tsv":
      with open(filename,encoding='utf-8',errors='ignore') as file:
        tsv_file = csv.reader(file, delimiter="\t", quotechar='"')
        with open(filename+".txt", 'w') as f:
            totales=0
            for line in tsv_file:
                listaProcesada=line
                print("Procesando ",filename," id ",listaProcesada[0],"Totales:",totales)
                totales=totales+1

                if len(listaProcesada) == 5 and (listaProcesada[2] == 'OFF' or listaProcesada[2] == 'NON'):
                    listaProcesada[1]=tokenizarTexto(listaProcesada)
                    mapaLineas[filename]=listaProcesada
                    comentario = {
                        'id': listaProcesada[0],
                        'texto': listaProcesada[1],
                        'ofensividad': listaProcesada[2],
                        'genero': listaProcesada[3],
                        'plataforma': listaProcesada[4]
                    }

                    if(filename=="train.tsv"):
                      comentarios_training.append(comentario)
                    else:
                      comentarios_dev.append(comentario)
                    f.write(listaProcesada[0])
                    f.write("\n")
                    f.write(listaProcesada[1])
                    f.write("\n")
                    f.write(listaProcesada[2])
                    f.write("\n")
                    f.write(listaProcesada[3])
                    f.write("\n")
                    f.write(listaProcesada[4])
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                else:
                    print("Error: La línea no tiene la longitud esperada.")'''

# %% [markdown]
# ### Carga de test.tsv

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# %%
import csv

# %%
def tokenizarTexto(lista):
    texto=nlp(lista[1])
    tokens=[]
    textoProcesado=""
    for token in texto:
        if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
            #tokens.append(token.text.lower()) #la pasamos a minúscula
            tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula
    textoProcesado=" ".join(tokens)
    return textoProcesado

comentarios_test=[]
filename="test.tsv"
with open(filename,encoding='utf-8',errors='ignore') as file:
        tsv_file = csv.reader(file, delimiter="\t", quotechar='"')
        totales=0
        with open(filename+".txt", 'w') as f:
            for line in tsv_file:
                listaProcesada=line
                totales=totales+1
                listaProcesada[1]=tokenizarTexto(listaProcesada)
                comentario = {
                        'id': listaProcesada[0],
                        'texto': listaProcesada[1],
                        'ofensividad': "",
                        'genero': listaProcesada[2],
                        'plataforma': listaProcesada[3]
                    }
                #print(comentario)
                #print(listaProcesada[0])
                comentarios_test.append(comentario)
                f.write(listaProcesada[0])
                f.write("\n")
                f.write(listaProcesada[1])
                f.write("\n")
                f.write(listaProcesada[2])
                f.write("\n")
                f.write(listaProcesada[3])
                f.write("\n")
                f.write("-----------------------")
                f.write("\n")
                f.write("-----------------------")
                f.write("\n")
            f.close()

# %%
comentarios_test.pop(0)
print("Mostrando el primer comentario:", comentarios_test[0]["texto"])

# %% [markdown]
# ### Procesado normal

# %%
def preprocesarLista(lista): #Función para quitar comillas y corchetes
    listaAux=[]
    for elemento in lista:
        listaAux.append(elemento.replace("'","").replace("]","").replace("[",""))
    return listaAux

def tokenizarTexto(lista):
    texto=nlp(lista[1])
    tokens=[]
    textoProcesado=""
    for token in texto:
        if token.text.isalpha() and not token.is_stop: #Quitamos signos de puntuación y stop words
            tokens.append(token.lemma_.lower()) #Reducimos a la raiz cada palabra y la pasamos a minúscula
    textoProcesado=" ".join(tokens)
    return textoProcesado

########################CARGA DE DATOS##########################
import os 
import glob   #Lectura y procesado de los archivos
import chardet
import openpyxl
import csv
import pandas as pd
path = os.chdir("/content/drive/MyDrive/PLN/Proyecto")
os.getcwd()

mapaLineas={}
comentarios_training = []
comentarios_dev = []
for filename in glob.glob('*.tsv'):  #Lectura de todos los archivos xlsx
    print(filename)
    if filename!="test.tsv":
      with open(filename,encoding='utf-8',errors='ignore') as file:
        tsv_file = csv.reader(file, delimiter="\t", quotechar='"')
        with open(filename+".txt", 'w') as f:
            totales=0
            for line in tsv_file:
                listaProcesada=line
                totales=totales+1

                if len(listaProcesada) == 5 and (listaProcesada[2] == 'OFF' or listaProcesada[2] == 'NON'):
                    listaProcesada[1]=tokenizarTexto(listaProcesada)
                    mapaLineas[filename]=listaProcesada
                    comentario = {
                        'id': listaProcesada[0],
                        'texto': listaProcesada[1],
                        'ofensividad': listaProcesada[2],
                        'genero': listaProcesada[3],
                        'plataforma': listaProcesada[4]
                    }

                    if(filename=="train.tsv"):
                      comentarios_training.append(comentario)
                    else:
                      comentarios_dev.append(comentario)
                    f.write(listaProcesada[0])
                    f.write("\n")
                    f.write(listaProcesada[1])
                    f.write("\n")
                    f.write(listaProcesada[2])
                    f.write("\n")
                    f.write(listaProcesada[3])
                    f.write("\n")
                    f.write(listaProcesada[4])
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                    f.write("-----------------------")
                    f.write("\n")
                else:
                    print("Error: La línea no tiene la longitud esperada.")
# Out:
# train.tsv
# Error: La línea no tiene la longitud esperada.
# dev.tsv
# Error: La línea no tiene la longitud esperada.
# test.tsv

# %% [markdown]
# ### Comprobación del corpus

# %%
contador_NON = 0
contador_OFF = 0

# Recorrer los comentarios y contar
for comentario in comentarios_training:
    if comentario['ofensividad'] == 'NON':
        contador_NON += 1
    elif comentario['ofensividad'] == 'OFF':
        contador_OFF += 1

# Imprimir los resultados
print(f"Comentarios no ofensivos (NON): {contador_NON}")
print(f"Comentarios ofensivos (OFF): {contador_OFF}")
# Out:
# Comentarios no ofensivos (NON): 14447
# Comentarios ofensivos (OFF): 2263

# %%
texto_comentarios_training = []
ofensividad_comentarios_training = []

# Recorrer los comentarios y guardar la información en las listas
for comentario in comentarios_training:
    texto_comentarios_training.append(comentario['texto'])
    ofensividad_comentarios_training.append(comentario['ofensividad'])
    print("Ofensividad: ", comentario["ofensividad"])

# Comprobar que las listas tienen el mismo tamaño
assert len(texto_comentarios_training) == len(ofensividad_comentarios_training), "Las listas tienen diferente tamaño"
# Out:
# Streaming output truncated to the last 5000 lines.
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# Ofensividad:  NON
# ...
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF
# Ofensividad:  OFF

# %%
texto_comentarios_test = []

# Recorrer los comentarios y guardar la información en las listas
for comentario in comentarios_test:
    texto_comentarios_test.append(comentario['texto'])

# Imprimir los comentarios training
for i in range(len(texto_comentarios_training)):
    print(f"Comentario {i + 1}:")
    print(f"Texto: {texto_comentarios_training[i]}")
    print(f"Ofensividad: {ofensividad_comentarios_training[i]}")
    print("---------------------------")
# Out:
# Streaming output truncated to the last 5000 lines.
# Comentario 15461:
# Texto: perro llegar pudretir cárcel cabron
# Ofensividad: OFF
# ---------------------------
# Comentario 15462:
# Texto: pringada psicologo underground
# Ofensividad: OFF
# ---------------------------
# Comentario 15463:
# Texto: náusea eruptos fingido volver comida poder next bañar plz
# Ofensividad: OFF
# ---------------------------
# Comentario 15464:
# Texto: gata cara malo persona
# Ofensividad: OFF
# ---------------------------
# Comentario 15465:
# Texto: sos mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15466:
# Texto: pelotudo
# Ofensividad: OFF
# ---------------------------
# Comentario 15467:
# Texto: maldita acosadora
# Ofensividad: OFF
# ---------------------------
# Comentario 15468:
# Texto: game over ridicula
# Ofensividad: OFF
# ---------------------------
# Comentario 15469:
# Texto: idiotir chico próximo ver
# Ofensividad: OFF
# ---------------------------
# Comentario 15470:
# Texto: edita tía ir grabar sitio grar sitio querer posturea
# Ofensividad: OFF
# ---------------------------
# Comentario 15471:
# Texto: cagar decir youtube móvil cago salir vídeo olor emanar truño pensar deber acabar vídeo persona personalidad truño acabar soltar venga dejar limpiar
# Ofensividad: OFF
# ---------------------------
# Comentario 15472:
# Texto: pensar voz mierda lleva tener cara precioso
# Ofensividad: OFF
# ---------------------------
# Comentario 15473:
# Texto: payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15474:
# Texto: windy gano concurso retrasado mental
# Ofensividad: OFF
# ---------------------------
# Comentario 15475:
# Texto: guarra t amar
# Ofensividad: OFF
# ---------------------------
# Comentario 15476:
# Texto: cosa claro huevo subir mierda artista
# Ofensividad: OFF
# ---------------------------
# Comentario 15477:
# Texto: presidente tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 15478:
# Texto: cry turboplanta respirar guindi desea hipócrita sos videos insultando metiéndote físico lisbet vistima windy piensa cerebro tetas favor
# Ofensividad: OFF
# ---------------------------
# Comentario 15479:
# Texto: subes video cacho mierda ostia mundo esperar v
# Ofensividad: OFF
# ---------------------------
# Comentario 15480:
# Texto: marca agua pantalla payasa xd inmaduro x dios mentalidad niña
# Ofensividad: OFF
# ---------------------------
# Comentario 15481:
# Texto: suscribir mierda v
# Ofensividad: OFF
# ---------------------------
# Comentario 15482:
# Texto: locar loca shakira
# Ofensividad: OFF
# ---------------------------
# Comentario 15483:
# Texto: racista
# Ofensividad: OFF
# ---------------------------
# Comentario 15484:
# Texto: valiente inculta ridicula
# Ofensividad: OFF
# ---------------------------
# Comentario 15485:
# Texto: oooh perra auron vive
# Ofensividad: OFF
# ---------------------------
# Comentario 15486:
# Texto: basura basura basura miare
# Ofensividad: OFF
# ---------------------------
# Comentario 15487:
# Texto: estupido
# Ofensividad: OFF
# ---------------------------
# Comentario 15488:
# Texto: llamar pon denuncia falso robar perro madre locar
# Ofensividad: OFF
# ---------------------------
# Comentario 15489:
# Texto: bloquea tweet gente madre caníbal ladrón payasos
# Ofensividad: OFF
# ---------------------------
# Comentario 15490:
# Texto: tocar
# Ofensividad: OFF
# ---------------------------
# Comentario 15491:
# Texto: maldita delincuente
# Ofensividad: OFF
# ---------------------------
# Comentario 15492:
# Texto: windi mentira cabeza perra seguir seguir v
# Ofensividad: OFF
# ---------------------------
# Comentario 15493:
# Texto: finalidad puta mierdo video oreja orco daltonico disfraz natural
# Ofensividad: OFF
# ---------------------------
# Comentario 15494:
# Texto: serás crítico respeto opinión entretener yo fan subs fan dejar criticar él favor criticar youtubers demandar chaval criticar
# Ofensividad: OFF
# ---------------------------
# Comentario 15495:
# Texto: tonto pata
# Ofensividad: OFF
# ---------------------------
# Comentario 15496:
# Texto: pensar wismichu burlar peruano hdpt
# Ofensividad: OFF
# ---------------------------
# Comentario 15497:
# Texto: gorda asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 15498:
# Texto: llevar par año esperar largar payasa
# Ofensividad: OFF
# ---------------------------
# Comentario 15499:
# Texto: justificar idiota jajaj solito delatar robar tiempo tener acceso celular entender kimberly decidir alejar él juan razón tener video actualidad tiempo facil deducir sinceramente rollo imbecil quedo imbecil
# Ofensividad: OFF
# ---------------------------
# Comentario 15500:
# Texto: cariño post ridiculo
# Ofensividad: OFF
# ---------------------------
# Comentario 15501:
# Texto: traer joya wismi puto calvo xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15502:
# Texto: zorro zorra hipócrita cosa
# Ofensividad: OFF
# ---------------------------
# Comentario 15503:
# Texto: dalacito violadorcito debería burlarte persona intentar hundirte vida ocasión xdxdxd
# Ofensividad: OFF
# ---------------------------
# Comentario 15504:
# Texto: decir dar espalda alguien ayudar mirar doble cara asco persona
# Ofensividad: OFF
# ---------------------------
# Comentario 15505:
# Texto: locir
# Ofensividad: OFF
# ---------------------------
# Comentario 15506:
# Texto: cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15507:
# Texto: chalir pinche morro exajerado
# Ofensividad: OFF
# ---------------------------
# Comentario 15508:
# Texto: dulceida hija quitate raya pelo ridicular
# Ofensividad: OFF
# ---------------------------
# Comentario 15509:
# Texto: jajajajajajajajaja maldita locaaaaa
# Ofensividad: OFF
# ---------------------------
# Comentario 15510:
# Texto: gordo v
# Ofensividad: OFF
# ---------------------------
# Comentario 15511:
# Texto: mierda auron piojosoplay
# Ofensividad: OFF
# ---------------------------
# Comentario 15512:
# Texto: ir tú mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15513:
# Texto: maldito windy hrmno
# Ofensividad: OFF
# ---------------------------
# Comentario 15514:
# Texto: siquiera estabir gordo nmmz traumar ve psicólogo
# Ofensividad: OFF
# ---------------------------
# Comentario 15515:
# Texto: gustar observar cara niñata tener hermana hacer tipo comentario lamentable pensar simple influencer persona soportar tipo comentario optimo abrir él cerebro
# Ofensividad: OFF
# ---------------------------
# Comentario 15516:
# Texto: feo marido
# Ofensividad: OFF
# ---------------------------
# Comentario 15517:
# Texto: puto da él
# Ofensividad: OFF
# ---------------------------
# Comentario 15518:
# Texto: dalas tonto vender juan haber revés estar decir atacar q dejar hablar gente gusto hablar gustar atacar sentido
# Ofensividad: OFF
# ---------------------------
# Comentario 15519:
# Texto: ojalo vuelva maldito dramatico
# Ofensividad: OFF
# ---------------------------
# Comentario 15520:
# Texto: tonta t sta escuchar decir k venir vetir hospital lleno decir
# Ofensividad: OFF
# ---------------------------
# Comentario 15521:
# Texto: nar horrible loca pelirrojo
# Ofensividad: OFF
# ---------------------------
# Comentario 15522:
# Texto: endermo sos terrible cagon rompio boca metro tén forrir
# Ofensividad: OFF
# ---------------------------
# Comentario 15523:
# Texto: gorda
# Ofensividad: OFF
# ---------------------------
# Comentario 15524:
# Texto: pareces putamente subnormal tener cosa
# Ofensividad: OFF
# ---------------------------
# Comentario 15525:
# Texto: jajaja jajajar ridícular
# Ofensividad: OFF
# ---------------------------
# Comentario 15526:
# Texto: menuda cara tonta tién pegar fuerte pequeño
# Ofensividad: OFF
# ---------------------------
# Comentario 15527:
# Texto: falsa mojigatar
# Ofensividad: OFF
# ---------------------------
# Comentario 15528:
# Texto: nomas ridiculo
# Ofensividad: OFF
# ---------------------------
# Comentario 15529:
# Texto: desuscribo javi actitud prometíar enfrentándote dross exponiendolo mierdanann ciber delincuente haber doblegar youtube confiar ojalá tengar arrepentirtir
# Ofensividad: OFF
# ---------------------------
# Comentario 15530:
# Texto: pinche chillon
# Ofensividad: OFF
# ---------------------------
# Comentario 15531:
# Texto: sentir ofendido wismichu cabrón
# Ofensividad: OFF
# ---------------------------
# Comentario 15532:
# Texto: pasar año sigue patética influencia cojonudo joven señoro arruinar vida límite espabila pedazo nauseabunda
# Ofensividad: OFF
# ---------------------------
# Comentario 15533:
# Texto: patético
# Ofensividad: OFF
# ---------------------------
# Comentario 15534:
# Texto: conocer shampoo ser otaku calvir
# Ofensividad: OFF
# ---------------------------
# Comentario 15535:
# Texto: perra seguir seguir v
# Ofensividad: OFF
# ---------------------------
# Comentario 15536:
# Texto: tristar tipa v
# Ofensividad: OFF
# ---------------------------
# Comentario 15537:
# Texto: parez tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 15538:
# Texto: tengar pelo tonto debatidle eh
# Ofensividad: OFF
# ---------------------------
# Comentario 15539:
# Texto: jamás volver tonta
# Ofensividad: OFF
# ---------------------------
# Comentario 15540:
# Texto: persona acto alguien acusa muestra realmente
# Ofensividad: OFF
# ---------------------------
# Comentario 15541:
# Texto: buscar víctima show aburrido morder lengua escupir caer él mierda cara hacer morder él apoyar bualaaaa hipócritar señoritar
# Ofensividad: OFF
# ---------------------------
# Comentario 15542:
# Texto: wismichu serás toronto toronto tonto wismichu
# Ofensividad: OFF
# ---------------------------
# Comentario 15543:
# Texto: puto otaku
# Ofensividad: OFF
# ---------------------------
# Comentario 15544:
# Texto: payaso culiao dejar hablar wea funcionar cosa
# Ofensividad: OFF
# ---------------------------
# Comentario 15545:
# Texto: señoraaaa criado ir mano totalmente canal muerto yaa n vuelva youtube hija visita tener risa
# Ofensividad: OFF
# ---------------------------
# Comentario 15546:
# Texto: puto rubius
# Ofensividad: OFF
# ---------------------------
# Comentario 15547:
# Texto: mentiroso salvaje
# Ofensividad: OFF
# ---------------------------
# Comentario 15548:
# Texto: suscribo perder canal mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15549:
# Texto: gorda imbécil
# Ofensividad: OFF
# ---------------------------
# Comentario 15550:
# Texto: mamser morra quitar risa cool reír cosa pendeja jagir
# Ofensividad: OFF
# ---------------------------
# Comentario 15551:
# Texto: gorda feo
# Ofensividad: OFF
# ---------------------------
# Comentario 15552:
# Texto: dross comprar pescado madre infierno
# Ofensividad: OFF
# ---------------------------
# Comentario 15553:
# Texto: so alto mogolico morite pelotudo
# Ofensividad: OFF
# ---------------------------
# Comentario 15554:
# Texto: increíble cambiar gente falta vida social real destruir cerebro amiguita tos joven estudiar aprender hablar parecer sobreactuado estaba rellenito persona olvidar neurona alto contenido graso rebajaste xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15555:
# Texto: hater falsa
# Ofensividad: OFF
# ---------------------------
# Comentario 15556:
# Texto: estúpidamente inútil
# Ofensividad: OFF
# ---------------------------
# Comentario 15557:
# Texto: patético
# Ofensividad: OFF
# ---------------------------
# Comentario 15558:
# Texto: feo
# Ofensividad: OFF
# ---------------------------
# Comentario 15559:
# Texto: gordo boluda
# Ofensividad: OFF
# ---------------------------
# Comentario 15560:
# Texto: madre payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15561:
# Texto: oye wismichu tener huevo venirte pirineos benasque grabar vídeo norman mix subistar daba camiseta comics etc dar bienvenida pueblo llamar villanova vengar ver yo benasque villanova juro tener huevo oseo faltar forma vuaaa increíble ir acaso invitar
# Ofensividad: OFF
# ---------------------------
# Comentario 15562:
# Texto: hijoputa vídeo w podcast
# Ofensividad: OFF
# ---------------------------
# Comentario 15563:
# Texto: parecer pase osea perfecto javi dannan dross dannar dross engreído pase dejenlo rincorosos dross mierda dannar amiguir auronplay wismichu
# Ofensividad: OFF
# ---------------------------
# Comentario 15564:
# Texto: creer pelirroja porquería tanto lik mentir sorteo haber él meter cpn youtubers ganar visita
# Ofensividad: OFF
# ---------------------------
# Comentario 15565:
# Texto: decir viejo delincuente
# Ofensividad: OFF
# ---------------------------
# Comentario 15566:
# Texto: ascir bola mierda cubierto ropa jajajajo
# Ofensividad: OFF
# ---------------------------
# Comentario 15567:
# Texto: hijo mil puta pasar dj mario
# Ofensividad: OFF
# ---------------------------
# Comentario 15568:
# Texto: mujer asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 15569:
# Texto: auron calvo retrasado dese tiempo inmemorabl
# Ofensividad: OFF
# ---------------------------
# Comentario 15570:
# Texto: jajajjajajjjajajajajajajjajajajajajajajjajajajajajajjajajajajajjajajjaa merecer pendeja
# Ofensividad: OFF
# ---------------------------
# Comentario 15571:
# Texto: denuncier canal chao bruja
# Ofensividad: OFF
# ---------------------------
# Comentario 15572:
# Texto: asquerosa amar
# Ofensividad: OFF
# ---------------------------
# Comentario 15573:
# Texto: cara loca jaja
# Ofensividad: OFF
# ---------------------------
# Comentario 15574:
# Texto: cabron seguirar ver video meo risa v tomo bar ver risa
# Ofensividad: OFF
# ---------------------------
# Comentario 15575:
# Texto: tranquilo tonto ridiculir asegurar
# Ofensividad: OFF
# ---------------------------
# Comentario 15576:
# Texto: paz dross paz trozo mierdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15577:
# Texto: alguien decir flaco travesti vas cojer amigo
# Ofensividad: OFF
# ---------------------------
# Comentario 15578:
# Texto: feo persona atrevser hacer él javi magnitud hicistar querer formar team miare información javi malo persona pedir perdón sea egocéntrico
# Ofensividad: OFF
# ---------------------------
# Comentario 15579:
# Texto: susto dar métetir cueva salir estar sol porfavor
# Ofensividad: OFF
# ---------------------------
# Comentario 15580:
# Texto: aburr anda criticar comentir hermana ignificar patetio unico patetico
# Ofensividad: OFF
# ---------------------------
# Comentario 15581:
# Texto: cobarde
# Ofensividad: OFF
# ---------------------------
# Comentario 15582:
# Texto: sindrome kim hahahah patetico
# Ofensividad: OFF
# ---------------------------
# Comentario 15583:
# Texto: esperar llegar cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15584:
# Texto: ibai cara subnormal
# Ofensividad: OFF
# ---------------------------
# Comentario 15585:
# Texto: zorrs quedar perra busca fama
# Ofensividad: OFF
# ---------------------------
# Comentario 15586:
# Texto: mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15587:
# Texto: aweonao das asco encerio alguien enfermo culiao descriminacion machito culiao cuerpos hermosos listo amor ego ámense derecho crei llegar opinar alguien eri aweonao extremo
# Ofensividad: OFF
# ---------------------------
# Comentario 15588:
# Texto: amigo as jajajajajajajajajjajajajaja parez choni
# Ofensividad: OFF
# ---------------------------
# Comentario 15589:
# Texto: chon gordo emo jaao
# Ofensividad: OFF
# ---------------------------
# Comentario 15590:
# Texto: suerte caes muer muer subir video joputa
# Ofensividad: OFF
# ---------------------------
# Comentario 15591:
# Texto: fan dejar vaga subir video rápido cacho mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15592:
# Texto: acusar ded hipócrita agradecido isir jugada sucio rastrera horrible feo q iso amigo q triste
# Ofensividad: OFF
# ---------------------------
# Comentario 15593:
# Texto: pedir perdón subir video contradizar título vídeo clickbait basura
# Ofensividad: OFF
# ---------------------------
# Comentario 15594:
# Texto: k feo
# Ofensividad: OFF
# ---------------------------
# Comentario 15595:
# Texto: tío lindo caga mental ve psiquiatra miare ayudar vas brillar vida pleno olvidar miare cuidar salud mental ojalá vear joderrr
# Ofensividad: OFF
# ---------------------------
# Comentario 15596:
# Texto: maldita acosadora v
# Ofensividad: OFF
# ---------------------------
# Comentario 15597:
# Texto: ridícula
# Ofensividad: OFF
# ---------------------------
# Comentario 15598:
# Texto: sos tontar dar morir persona
# Ofensividad: OFF
# ---------------------------
# Comentario 15599:
# Texto: venir felicitarte video respuesta safada desvergonzada pautips estupendo loca atrevir atacarte visto capacidad intelectual paraello siquiera sentido comun auto sabotearse ves abrir bocota entiendo molestia causar gracia forma exponer cosa osea conserva humor jajaka
# Ofensividad: OFF
# ---------------------------
# Comentario 15600:
# Texto: pregunta caer viejo explotar universo
# Ofensividad: OFF
# ---------------------------
# Comentario 15601:
# Texto: windy favor dejar acosar youtubers malo entender video descrimín razon odiar
# Ofensividad: OFF
# ---------------------------
# Comentario 15602:
# Texto: lllegar pincho windy serio cambiar vida dejar hipocrito doble moral
# Ofensividad: OFF
# ---------------------------
# Comentario 15603:
# Texto: tia dulceida follariar melon
# Ofensividad: OFF
# ---------------------------
# Comentario 15604:
# Texto: idiota
# Ofensividad: OFF
# ---------------------------
# Comentario 15605:
# Texto: basico nace ameba bloqueame resto haters gente criticar basica ofendidita tener bloquear gente aceptas critica vida perfecto chicar tener critica gente gustar mierda asumelo
# Ofensividad: OFF
# ---------------------------
# Comentario 15606:
# Texto: vendido decir negativo serie seguro pensar personaje nano puta mierdo mario casa cambio diz gustar comprado netflix multinacional amo universo
# Ofensividad: OFF
# ---------------------------
# Comentario 15607:
# Texto: ashhhh aprender sacar él provecho cuerpo gordo operado
# Ofensividad: OFF
# ---------------------------
# Comentario 15608:
# Texto: pinche miare robar perro
# Ofensividad: OFF
# ---------------------------
# Comentario 15609:
# Texto: perra fake deberiar cancelar él fast
# Ofensividad: OFF
# ---------------------------
# Comentario 15610:
# Texto: falsa andatar
# Ofensividad: OFF
# ---------------------------
# Comentario 15611:
# Texto: cringe patético hipocrita
# Ofensividad: OFF
# ---------------------------
# Comentario 15612:
# Texto: admit pringada jajjaa métetir hate quepa
# Ofensividad: OFF
# ---------------------------
# Comentario 15613:
# Texto: bollera viejo bollera joven jajajajo
# Ofensividad: OFF
# ---------------------------
# Comentario 15614:
# Texto: uffff apetecer comer luchuga subnormal
# Ofensividad: OFF
# ---------------------------
# Comentario 15615:
# Texto: percebes carolina notar tener complejo juntar soyunapringado destacar parecer guapo inseguridad notar falsedad caer
# Ofensividad: OFF
# ---------------------------
# Comentario 15616:
# Texto: cállate orco seboso xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15617:
# Texto: dalas promocionar fur fun ilusionar seguidor comprar juego mierda dolar mierda criticar popularidad
# Ofensividad: OFF
# ---------------------------
# Comentario 15618:
# Texto: ibai lameculo
# Ofensividad: OFF
# ---------------------------
# Comentario 15619:
# Texto: malo gente windy
# Ofensividad: OFF
# ---------------------------
# Comentario 15620:
# Texto: hombre cobarde mentiroso
# Ofensividad: OFF
# ---------------------------
# Comentario 15621:
# Texto: payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15622:
# Texto: feo xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15623:
# Texto: sonar extraño agrar auronplay razón resultar molesto entender gente ver wismichu directamente plantilla sentir físico asco repulsión
# Ofensividad: OFF
# ---------------------------
# Comentario 15624:
# Texto: mezcla loca inocencia interrumpido anabel muñeca jajajar
# Ofensividad: OFF
# ---------------------------
# Comentario 15625:
# Texto: man gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 15626:
# Texto: fea estar
# Ofensividad: OFF
# ---------------------------
# Comentario 15627:
# Texto: estar idiotar windy
# Ofensividad: OFF
# ---------------------------
# Comentario 15628:
# Texto: super malagradecida tipa culpe tumor comportamiento vibora
# Ofensividad: OFF
# ---------------------------
# Comentario 15629:
# Texto: pensar existir gente mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15630:
# Texto: tir tonto dio neurona peleada mamada dalas importante cosa defender él comer él huevo aplaudir canal dedicado poder esperar alguien
# Ofensividad: OFF
# ---------------------------
# Comentario 15631:
# Texto: puta pena q da
# Ofensividad: OFF
# ---------------------------
# Comentario 15632:
# Texto: perdona gordo boyera vis vis
# Ofensividad: OFF
# ---------------------------
# Comentario 15633:
# Texto: vos existis payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15634:
# Texto: aceptar payaso payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15635:
# Texto: pendeja asustar marlos
# Ofensividad: OFF
# ---------------------------
# Comentario 15636:
# Texto: demasiado insullto gratuito caíste persona brular ingl ir inglés vivir mundo trabajar internet deber estupir
# Ofensividad: OFF
# ---------------------------
# Comentario 15637:
# Texto: independientemente jeiters decir ñiñiñiñiñi odiar comunidad comprend bastar contenido valer bolivar
# Ofensividad: OFF
# ---------------------------
# Comentario 15638:
# Texto: dejar mentir maldito entrar youtube video relacionado arto vetir carcel
# Ofensividad: OFF
# ---------------------------
# Comentario 15639:
# Texto: hola gordar mierda cerda
# Ofensividad: OFF
# ---------------------------
# Comentario 15640:
# Texto: querer vender cuerpo subir vide tú especie twerk super nefasto promocionar pack hipocresia pd rubius seas malo
# Ofensividad: OFF
# ---------------------------
# Comentario 15641:
# Texto: cara loca mandar
# Ofensividad: OFF
# ---------------------------
# Comentario 15642:
# Texto: desear jpelirrojo cague esty subir video plan gana tentar jpelirrojo liar él parda tontería
# Ofensividad: OFF
# ---------------------------
# Comentario 15643:
# Texto: facha
# Ofensividad: OFF
# ---------------------------
# Comentario 15644:
# Texto: vas circo payaso listo
# Ofensividad: OFF
# ---------------------------
# Comentario 15645:
# Texto: ridiculo epar mentir
# Ofensividad: OFF
# ---------------------------
# Comentario 15646:
# Texto: cagarmir cara mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15647:
# Texto: jaja malo juego estúpido vas jugar bn ganar
# Ofensividad: OFF
# ---------------------------
# Comentario 15648:
# Texto: oir tonto respetar opinión
# Ofensividad: OFF
# ---------------------------
# Comentario 15649:
# Texto: madre loca
# Ofensividad: OFF
# ---------------------------
# Comentario 15650:
# Texto: mierda gente estúpido contar historia idolatra pivo asco gente vedad posdata haz deporte ir palmar él año asfixiado estúpida
# Ofensividad: OFF
# ---------------------------
# Comentario 15651:
# Texto: imbécil hora hora vicio gears cuphead ori cabronazo
# Ofensividad: OFF
# ---------------------------
# Comentario 15652:
# Texto: culia feo xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15653:
# Texto: detesto musculoso cabezo hueco hipócrita jordi hijoputa quedar corto
# Ofensividad: OFF
# ---------------------------
# Comentario 15654:
# Texto: orco
# Ofensividad: OFF
# ---------------------------
# Comentario 15655:
# Texto: tio tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 15656:
# Texto: jajajajaja gorda mantecós sincero kilo tener
# Ofensividad: OFF
# ---------------------------
# Comentario 15657:
# Texto: lavate manati infraser gorda
# Ofensividad: OFF
# ---------------------------
# Comentario 15658:
# Texto: dejar molestar dala tipo sufrir difamación severo manchar permanentemente imagen público acosar sigues cosa va empezar sufrir acoso ir limpiar imagen ir merecer mentirosa
# Ofensividad: OFF
# ---------------------------
# Comentario 15659:
# Texto: eh patética penosa actuacion windy recibir notificación mega némesis
# Ofensividad: OFF
# ---------------------------
# Comentario 15660:
# Texto: hijo put q metisteis rubius cara gana visita imbecil q asco dar
# Ofensividad: OFF
# ---------------------------
# Comentario 15661:
# Texto: gustar vázquez resultar vomitivo destilar veneno malo bar sonrisa rijós rojós viejo verde aficionado querub asco entender asqueroso rijo él malo bar gustar entender
# Ofensividad: OFF
# ---------------------------
# Comentario 15662:
# Texto: frente cabron
# Ofensividad: OFF
# ---------------------------
# Comentario 15663:
# Texto: madre loca
# Ofensividad: OFF
# ---------------------------
# Comentario 15664:
# Texto: payasar operate pa delgazar gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 15665:
# Texto: manipulador loco llegar punto decir abuelo cantar viva españa salir tipo saludo fascista ver clase persona
# Ofensividad: OFF
# ---------------------------
# Comentario 15666:
# Texto: tontar patreon foto erotica volveria millonario cuerpo cara
# Ofensividad: OFF
# ---------------------------
# Comentario 15667:
# Texto: puto payaso mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15668:
# Texto: roba perro ladronar víctima debería carcel
# Ofensividad: OFF
# ---------------------------
# Comentario 15669:
# Texto: emreneted nev sedoj et ne yer arabráb us erdam im euq olehc anu aroñser atse euq erdam im ed adaromane etnematelpmoc átse aroñes atse euq aíroet
# Ofensividad: OFF
# ---------------------------
# Comentario 15670:
# Texto: limpiarte cagar fué pudistar sentar tú bidé vayas pink flamingo vida freak penoso resaltable encantar insalubre obés morbido caracter deleznable egocentrica criticar dema original video contenido unico esconder niňa pijo inscociable creido envidiós rencorós vacio cortney love vida maruja viejovir circo par temporada rodar peor pueblo ameba sobrealimentado
# Ofensividad: OFF
# ---------------------------
# Comentario 15671:
# Texto: saca contexto v mujer criticar considera burlar mierdar pasar estúpido cabeza
# Ofensividad: OFF
# ---------------------------
# Comentario 15672:
# Texto: vulgar
# Ofensividad: OFF
# ---------------------------
# Comentario 15673:
# Texto: fan pedazo mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15674:
# Texto: mundo etc etc etc muestra cuerpo mayoría chico aumentar odio etc aument pornografia youtube
# Ofensividad: OFF
# ---------------------------
# Comentario 15675:
# Texto: belén linea cero presentador sálvame vuelv demostrar
# Ofensividad: OFF
# ---------------------------
# Comentario 15676:
# Texto: dejar mentir aprovechar seguir tirar puyita critico stream snipe pesado difamir denunciar denuncia dejar pasar tener visita canal diz mentira pasar estuvistir canal habia critico español decir injusto quitar canal ejemplo wildhater ver video so mentirós
# Ofensividad: OFF
# ---------------------------
# Comentario 15677:
# Texto: fea
# Ofensividad: OFF
# ---------------------------
# Comentario 15678:
# Texto: oye perro desgraciado dijiste subiría video debate lizbeth
# Ofensividad: OFF
# ---------------------------
# Comentario 15679:
# Texto: quitar loca embarazo psicológico raro explicación
# Ofensividad: OFF
# ---------------------------
# Comentario 15680:
# Texto: ser odiosooooooooooo subir maldito entrevista completaaaaao sentir serie terminar querer v
# Ofensividad: OFF
# ---------------------------
# Comentario 15681:
# Texto: falta respeto estar pisar cara supercotilla
# Ofensividad: OFF
# ---------------------------
# Comentario 15682:
# Texto: desgraciado
# Ofensividad: OFF
# ---------------------------
# Comentario 15683:
# Texto: miss andine mujer gamer ver comparar jajar da pena ajena
# Ofensividad: OFF
# ---------------------------
# Comentario 15684:
# Texto: malo feo fuistir
# Ofensividad: OFF
# ---------------------------
# Comentario 15685:
# Texto: alguien opinar juan dios completo pendejazo tonto etc tanto subs completo imbecil flipo xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15686:
# Texto: tonta culir jsjjs caer uwu
# Ofensividad: OFF
# ---------------------------
# Comentario 15687:
# Texto: marrana corral escapar
# Ofensividad: OFF
# ---------------------------
# Comentario 15688:
# Texto: feo va pivon jajajajajaj
# Ofensividad: OFF
# ---------------------------
# Comentario 15689:
# Texto: escribir letra letra comemir huevo
# Ofensividad: OFF
# ---------------------------
# Comentario 15690:
# Texto: dejatelo feo asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 15691:
# Texto: artista qlo lloron saber q estudiar art visual decir entregar trabajo suicidio doler maldito sensible
# Ofensividad: OFF
# ---------------------------
# Comentario 15692:
# Texto: miare millon sub mil views felicidades dar pena jpelirrojo jajajar dar euro cigarro
# Ofensividad: OFF
# ---------------------------
# Comentario 15693:
# Texto: personar mad repugnante ir abrir restaurante beer beaf and boobs prefier quierar animal vegano
# Ofensividad: OFF
# ---------------------------
# Comentario 15694:
# Texto: loca momento quedar
# Ofensividad: OFF
# ---------------------------
# Comentario 15695:
# Texto: busca patético rae salir foto niña
# Ofensividad: OFF
# ---------------------------
# Comentario 15696:
# Texto: dalas ojalá morar doloroso tío seguir insultarte dar
# Ofensividad: OFF
# ---------------------------
# Comentario 15697:
# Texto: robar contenido quejar robir robado estupir
# Ofensividad: OFF
# ---------------------------
# Comentario 15698:
# Texto: oir corxea tratastir mensaje mandar román ascir dar tío
# Ofensividad: OFF
# ---------------------------
# Comentario 15699:
# Texto: memir miare encajar perfil psicópata manipuladora obsesivo falta empatía irónico
# Ofensividad: OFF
# ---------------------------
# Comentario 15700:
# Texto: progre hipócrita moralisto hahaha wismiche amigu xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15701:
# Texto: materiales vídeo windy saltar papel higiénico cremir listo vídeo
# Ofensividad: OFF
# ---------------------------
# Comentario 15702:
# Texto: mirar feo joder
# Ofensividad: OFF
# ---------------------------
# Comentario 15703:
# Texto: puto da él cansar humillar él tardar subir video kun agüero
# Ofensividad: OFF
# ---------------------------
# Comentario 15704:
# Texto: gorda ahorcar nifa coca
# Ofensividad: OFF
# ---------------------------
# Comentario 15705:
# Texto: trozo mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15706:
# Texto: asco persona querer baniar youtubers an ayudar entu canal
# Ofensividad: OFF
# ---------------------------
# Comentario 15707:
# Texto: hipócrita roba perro
# Ofensividad: OFF
# ---------------------------
# Comentario 15708:
# Texto: joder ballena gordar odiar hetero
# Ofensividad: OFF
# ---------------------------
# Comentario 15709:
# Texto: payasa mina jajar saludo argentina dalas
# Ofensividad: OFF
# ---------------------------
# Comentario 15710:
# Texto: odiar jpelirrojo patético
# Ofensividad: OFF
# ---------------------------
# Comentario 15711:
# Texto: puto calvo
# Ofensividad: OFF
# ---------------------------
# Comentario 15712:
# Texto: mujer lik tener suponer subir video nopor echo
# Ofensividad: OFF
# ---------------------------
# Comentario 15713:
# Texto: hola miedo acabar descubrir ex puto psicópata cojones
# Ofensividad: OFF
# ---------------------------
# Comentario 15714:
# Texto: violador mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15715:
# Texto: celopan puto calvo
# Ofensividad: OFF
# ---------------------------
# Comentario 15716:
# Texto: maldito escoria televisivo
# Ofensividad: OFF
# ---------------------------
# Comentario 15717:
# Texto: concha
# Ofensividad: OFF
# ---------------------------
# Comentario 15718:
# Texto: panochudo creer badadun atrás noo badadun quebrar vista arañar tener motivo pasar persona daño kenia razón llama karma
# Ofensividad: OFF
# ---------------------------
# Comentario 15719:
# Texto: puto cobarde jordi responder callar pasar confinamiento salir casa pierna dialogo
# Ofensividad: OFF
# ---------------------------
# Comentario 15720:
# Texto: dejar hablar weas payaso reculiao
# Ofensividad: OFF
# ---------------------------
# Comentario 15721:
# Texto: tuuu pedazo fea derecho tener has pablo alboran querer quitarselo ole cojones derecho crees tener callar pinta llevas ridicula click piiiii piii piiii
# Ofensividad: OFF
# ---------------------------
# Comentario 15722:
# Texto: tir falso
# Ofensividad: OFF
# ---------------------------
# Comentario 15723:
# Texto: mover foca agonia
# Ofensividad: OFF
# ---------------------------
# Comentario 15724:
# Texto: hipocrita tipa creer defiéndetir javi echar perder canal
# Ofensividad: OFF
# ---------------------------
# Comentario 15725:
# Texto: gordo feminista insultar querer vida criticandolo tiempo libre ver
# Ofensividad: OFF
# ---------------------------
# Comentario 15726:
# Texto: miare vediar cosa defectuoso cosa subir precio mierda transacción
# Ofensividad: OFF
# ---------------------------
# Comentario 15727:
# Texto: eh bro tener fantasma correr investigar idiotar
# Ofensividad: OFF
# ---------------------------
# Comentario 15728:
# Texto: estupir grita
# Ofensividad: OFF
# ---------------------------
# Comentario 15729:
# Texto: puto
# Ofensividad: OFF
# ---------------------------
# Comentario 15730:
# Texto: hijo perra sigue vida
# Ofensividad: OFF
# ---------------------------
# Comentario 15731:
# Texto: gana video razon dannan mierda persona dejar like sigas subir material youtube tomar algoritmo pd notar vos creia señor oliveira saludo
# Ofensividad: OFF
# ---------------------------
# Comentario 15732:
# Texto: creser gordar
# Ofensividad: OFF
# ---------------------------
# Comentario 15733:
# Texto: hola recordar debil macho gana dominar penetrar gustar querer beso opresión
# Ofensividad: OFF
# ---------------------------
# Comentario 15734:
# Texto: minuto cosa saber caso descerebrado hablar descerebrado
# Ofensividad: OFF
# ---------------------------
# Comentario 15735:
# Texto: bañate cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15736:
# Texto: gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 15737:
# Texto: falso
# Ofensividad: OFF
# ---------------------------
# Comentario 15738:
# Texto: dalas puto
# Ofensividad: OFF
# ---------------------------
# Comentario 15739:
# Texto: programa televisión maleducado gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 15740:
# Texto: ver payaso
# Ofensividad: OFF
# ---------------------------
# Comentario 15741:
# Texto: wismichu extrañar joputar
# Ofensividad: OFF
# ---------------------------
# Comentario 15742:
# Texto: toronto toronto tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 15743:
# Texto: desaparecer echar manipuladora
# Ofensividad: OFF
# ---------------------------
# Comentario 15744:
# Texto: ja ja vendistir estupida sorteo subes suscriptor twiter desesperado mujer
# Ofensividad: OFF
# ---------------------------
# Comentario 15745:
# Texto: verda gordo falso
# Ofensividad: OFF
# ---------------------------
# Comentario 15746:
# Texto: maldito mujer mentirós
# Ofensividad: OFF
# ---------------------------
# Comentario 15747:
# Texto: hablas padre muerto chorrado loca
# Ofensividad: OFF
# ---------------------------
# Comentario 15748:
# Texto: hola basura traicionero l
# Ofensividad: OFF
# ---------------------------
# Comentario 15749:
# Texto: jordi hipocrita pedofilo caer agradir video persona desagradar
# Ofensividad: OFF
# ---------------------------
# Comentario 15750:
# Texto: pringada importar vida copyright
# Ofensividad: OFF
# ---------------------------
# Comentario 15751:
# Texto: argos lugar irás derechitar infierno
# Ofensividad: OFF
# ---------------------------
# Comentario 15752:
# Texto: conrazon youtube invitar windy perra otaku mujer platisco musico epico channel
# Ofensividad: OFF
# ---------------------------
# Comentario 15753:
# Texto: jajajja sigues ridícula
# Ofensividad: OFF
# ---------------------------
# Comentario 15754:
# Texto: cochina
# Ofensividad: OFF
# ---------------------------
# Comentario 15755:
# Texto: gordar
# Ofensividad: OFF
# ---------------------------
# Comentario 15756:
# Texto: ridículo tipa subir video llorar quejar james charles cosa avergonzar actitud ordinario reunión privado manipulación jeffree star shane cochinada amiguito vió lavar mano punta lloriqueo único esperar jeffree star aniquile públicamente video aburrir saludo chile
# Ofensividad: OFF
# ---------------------------
# Comentario 15757:
# Texto: miro imaginar viejo decir él pan tomate escapser decir jovencita acabar suicidar coche arder
# Ofensividad: OFF
# ---------------------------
# Comentario 15758:
# Texto: ascir viejo pena salir video gorda
# Ofensividad: OFF
# ---------------------------
# Comentario 15759:
# Texto: falso exponer infiel
# Ofensividad: OFF
# ---------------------------
# Comentario 15760:
# Texto: suscriptor gordo enferma mental sociedad enferma
# Ofensividad: OFF
# ---------------------------
# Comentario 15761:
# Texto: cosa pesado gorda pides respetar tener
# Ofensividad: OFF
# ---------------------------
# Comentario 15762:
# Texto: cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15763:
# Texto: deberías enseñarno foto argoz pinshe ladrona
# Ofensividad: OFF
# ---------------------------
# Comentario 15764:
# Texto: ver super patético decir mem sentido capacidad intelectual menor grano arena halagar él mem entender neta rabia váyanse sr red newtrollwsp querer mem xdd
# Ofensividad: OFF
# ---------------------------
# Comentario 15765:
# Texto: ir tú comer lechuga subnormal
# Ofensividad: OFF
# ---------------------------
# Comentario 15766:
# Texto: código dedreevil pasar ofrecia dinero colaboración pinche tetonar
# Ofensividad: OFF
# ---------------------------
# Comentario 15767:
# Texto: jaja estar pendejo
# Ofensividad: OFF
# ---------------------------
# Comentario 15768:
# Texto: tonto comprar ridiculo
# Ofensividad: OFF
# ---------------------------
# Comentario 15769:
# Texto: caía vas aspirar ramen ano
# Ofensividad: OFF
# ---------------------------
# Comentario 15770:
# Texto: tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 15771:
# Texto: gorda sucio
# Ofensividad: OFF
# ---------------------------
# Comentario 15772:
# Texto: pillar caco dejar coma
# Ofensividad: OFF
# ---------------------------
# Comentario 15773:
# Texto: aparte calvo sordo gordo otaku feo fufb
# Ofensividad: OFF
# ---------------------------
# Comentario 15774:
# Texto: ascir dar mujer mujerr video diciéndotar asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 15775:
# Texto: windy ridículo q pena q paisana
# Ofensividad: OFF
# ---------------------------
# Comentario 15776:
# Texto: borra comentario pelotudo
# Ofensividad: OFF
# ---------------------------
# Comentario 15777:
# Texto: hola camilo año querer calvo arruinanegocio leña ver ver poder
# Ofensividad: OFF
# ---------------------------
# Comentario 15778:
# Texto: agradecer olvidar ayuda falso
# Ofensividad: OFF
# ---------------------------
# Comentario 15779:
# Texto: gorda
# Ofensividad: OFF
# ---------------------------
# Comentario 15780:
# Texto: puto crinje
# Ofensividad: OFF
# ---------------------------
# Comentario 15781:
# Texto: naaaaaa perra merecer
# Ofensividad: OFF
# ---------------------------
# Comentario 15782:
# Texto: lávate pelo gomina cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 15783:
# Texto: tonto pelma
# Ofensividad: OFF
# ---------------------------
# Comentario 15784:
# Texto: estupida viejo canibal
# Ofensividad: OFF
# ---------------------------
# Comentario 15785:
# Texto: casualidad borrado lastima jajaja dalas mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15786:
# Texto: haco ber él siento gue boy morir ber persona fesorden ficico mental feminismo estremo igualdad
# Ofensividad: OFF
# ---------------------------
# Comentario 15787:
# Texto: mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15788:
# Texto: q gordo estúpido
# Ofensividad: OFF
# ---------------------------
# Comentario 15789:
# Texto: nauter doler ano violadas dalas
# Ofensividad: OFF
# ---------------------------
# Comentario 15790:
# Texto: banda hate estilo últimamente sentir video dalas centrar ambiente humor tóxico autofelación salido proporción meter él discusión siquiera vender canal polémica rollo tóxico
# Ofensividad: OFF
# ---------------------------
# Comentario 15791:
# Texto: sal mundo locar
# Ofensividad: OFF
# ---------------------------
# Comentario 15792:
# Texto: rick celopan gay
# Ofensividad: OFF
# ---------------------------
# Comentario 15793:
# Texto: fake ridícula vengo turbo ver arder
# Ofensividad: OFF
# ---------------------------
# Comentario 15794:
# Texto: ir youtube sos estúpida falsa
# Ofensividad: OFF
# ---------------------------
# Comentario 15795:
# Texto: historia razón miare querer destruir da él populismo fuerte loca gato
# Ofensividad: OFF
# ---------------------------
# Comentario 15796:
# Texto: ojalá padre entrar carcel maldito mustia acosadoro
# Ofensividad: OFF
# ---------------------------
# Comentario 15797:
# Texto: chic gorda engafado haah pringada seto cultura chingadera pelirrojo extensa introducion esperar conocer él vida haha
# Ofensividad: OFF
# ---------------------------
# Comentario 15798:
# Texto: wismichu servir criticar llorar crítica hipócrita mentiroso payaso falso
# Ofensividad: OFF
# ---------------------------
# Comentario 15799:
# Texto: illo gracia decir adio haplo significar coño xd pava novia melodramático haplo tener ser él
# Ofensividad: OFF
# ---------------------------
# Comentario 15800:
# Texto: diga windy celoso
# Ofensividad: OFF
# ---------------------------
# Comentario 15801:
# Texto: pringada gorda asqueroso xd
# Ofensividad: OFF
# ---------------------------
# Comentario 15802:
# Texto: riser feo
# Ofensividad: OFF
# ---------------------------
# Comentario 15803:
# Texto: nomas esperar windy haber contradecir dalas video haber totalmente víbora atacar
# Ofensividad: OFF
# ---------------------------
# Comentario 15804:
# Texto: idiota
# Ofensividad: OFF
# ---------------------------
# Comentario 15805:
# Texto: mirate espejo tirarte flores fea mierd
# Ofensividad: OFF
# ---------------------------
# Comentario 15806:
# Texto: dala querer hablar valer juan wey mam vergo perro cabrón mierdo etc
# Ofensividad: OFF
# ---------------------------
# Comentario 15807:
# Texto: encantar hija puta pie cabeza encantar intervención película llamado fan numero dej vencer fácilmente dej q meter poder opinar q quierasss qn quiera ánimo
# Ofensividad: OFF
# ---------------------------
# Comentario 15808:
# Texto: gorda asqueós mundo critiques seguro gente conocer estar lista numero criticado
# Ofensividad: OFF
# ---------------------------
# Comentario 15809:
# Texto: dala feo
# Ofensividad: OFF
# ---------------------------
# Comentario 15810:
# Texto: sigo creer mae hombre tomar hormona hombre miare honesta
# Ofensividad: OFF
# ---------------------------
# Comentario 15811:
# Texto: q ás pelotudo ás video asierto estupodo q contenido
# Ofensividad: OFF
# ---------------------------
# Comentario 15812:
# Texto: mejorar jajaja cagada deber jugar shooter gamer mostrar culo teta llegar
# Ofensividad: OFF
# ---------------------------
# Comentario 15813:
# Texto: che viejo loca
# Ofensividad: OFF
# ---------------------------
# Comentario 15814:
# Texto: nauter creer persona sensato sabio mentirós vo entendistar mecha polémica yordi crei llorar
# Ofensividad: OFF
# ---------------------------
# Comentario 15815:
# Texto: buscabas zorrar
# Ofensividad: OFF
# ---------------------------
# Comentario 15816:
# Texto: música puto yoshi pegar cola video
# Ofensividad: OFF
# ---------------------------
# Comentario 15817:
# Texto: maldito cobarde golpear mujer
# Ofensividad: OFF
# ---------------------------
# Comentario 15818:
# Texto: pendejo puñeta
# Ofensividad: OFF
# ---------------------------
# Comentario 15819:
# Texto: estúpir
# Ofensividad: OFF
# ---------------------------
# Comentario 15820:
# Texto: asqueroso familia delincuente ojalá i cárcel
# Ofensividad: OFF
# ---------------------------
# Comentario 15821:
# Texto: parez gótico pareces pinche pingüino nms v
# Ofensividad: OFF
# ---------------------------
# Comentario 15822:
# Texto: talvez fuistir gamer teneír jugar fornite free fire animal crossing re porfavor llamar gamer siquiera juego jasjajhaahhsja gamer teta culo cara bonito tener
# Ofensividad: OFF
# ---------------------------
# Comentario 15823:
# Texto: mirar llamar chico gamer tener derecho jugar videojuego asco hagar visita enseñar notar interesar juego cosa vetir plataforma manchar nombre chica gamer querer ver
# Ofensividad: OFF
# ---------------------------
# Comentario 15824:
# Texto: devuelveaargo robastir ojala justicia hacer juzgado tengas merecido maldita
# Ofensividad: OFF
# ---------------------------
# Comentario 15825:
# Texto: cortar pelo idiota
# Ofensividad: OFF
# ---------------------------
# Comentario 15826:
# Texto: dejar youtube viejo
# Ofensividad: OFF
# ---------------------------
# Comentario 15827:
# Texto: especial cabrón haber ocurrir
# Ofensividad: OFF
# ---------------------------
# Comentario 15828:
# Texto: dos puta pena da él
# Ofensividad: OFF
# ---------------------------
# Comentario 15829:
# Texto: volver tis video distir asco anónimo jsjjs
# Ofensividad: OFF
# ---------------------------
# Comentario 15830:
# Texto: cabrón loco jajajajajaja hablarer nenir
# Ofensividad: OFF
# ---------------------------
# Comentario 15831:
# Texto: chica tonto xd coger viola gurl
# Ofensividad: OFF
# ---------------------------
# Comentario 15832:
# Texto: pareces mounstruo transexual sentimiento corazon sal luz sol luz natural rebajar
# Ofensividad: OFF
# ---------------------------
# Comentario 15833:
# Texto: hipocresía dalasita mierdesita criticable mierdesita dross criticable simple dross tirar mierdesito eliminastir vídeocririca dross hipocresía
# Ofensividad: OFF
# ---------------------------
# Comentario 15834:
# Texto: hablas estupida malo jugar
# Ofensividad: OFF
# ---------------------------
# Comentario 15835:
# Texto: ayer wildhater caer genial video caser puto culo aclaración cosa inventar visita
# Ofensividad: OFF
# ---------------------------
# Comentario 15836:
# Texto: miren hipocresías preguntar haz ir andorra tema legal impedir
# Ofensividad: OFF
# ---------------------------
# Comentario 15837:
# Texto: feminista estupido
# Ofensividad: OFF
# ---------------------------
# Comentario 15838:
# Texto: hipócrita
# Ofensividad: OFF
# ---------------------------
# Comentario 15839:
# Texto: respir fuerte quedar feo escuchar él dema soltar tanto mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15840:
# Texto: puta vago
# Ofensividad: OFF
# ---------------------------
# Comentario 15841:
# Texto: echar persona falso conocer teamdalas uwu
# Ofensividad: OFF
# ---------------------------
# Comentario 15842:
# Texto: gorda cara kim jong
# Ofensividad: OFF
# ---------------------------
# Comentario 15843:
# Texto: cerrar canal maldito
# Ofensividad: OFF
# ---------------------------
# Comentario 15844:
# Texto: salvaste canal windy tonto chaval
# Ofensividad: OFF
# ---------------------------
# Comentario 15845:
# Texto: pena ver falso guapo tanto retoque
# Ofensividad: OFF
# ---------------------------
# Comentario 15846:
# Texto: miare mujerzuela
# Ofensividad: OFF
# ---------------------------
# Comentario 15847:
# Texto: sinceramente amiga fea tom insulto descriptivo canal sa él video simplemente horrorós queriar entender decia rostro desconcentrar intentar mirar fondo punto referencia lograr entenderte horripilante cara imposible ignorar peso razgo simplemente recordar mujer cuarenta tanto vivir trabajo comer casar tener relacion dedicar tienpo libre echado desarreglada cuarto salir enclaustrada comer parar resignado morir decir seas luz bir
# Ofensividad: OFF
# ---------------------------
# Comentario 15848:
# Texto: carajo alto estúpido gracia inútil
# Ofensividad: OFF
# ---------------------------
# Comentario 15849:
# Texto: notar tener frío eh cabrón
# Ofensividad: OFF
# ---------------------------
# Comentario 15850:
# Texto: hey joputar ver canoa escurrir
# Ofensividad: OFF
# ---------------------------
# Comentario 15851:
# Texto: cheverar video spoilers maldito sea
# Ofensividad: OFF
# ---------------------------
# Comentario 15852:
# Texto: chica valer hectarea verga jp hacer youtuber ganar seguidor criticar dema dejalo vivar vida gana
# Ofensividad: OFF
# ---------------------------
# Comentario 15853:
# Texto: pasar persona ser sincero talento mover chichis hacer él victimo vida ganar lamentable personaje llegar relevante mundo creer dios numero red social lamentable feminista jajajajaja pobre chica serio
# Ofensividad: OFF
# ---------------------------
# Comentario 15854:
# Texto: lizy hacer él dala salir jajajsjaj quedar ridícula
# Ofensividad: OFF
# ---------------------------
# Comentario 15855:
# Texto: windy perdónenmir enseñar escote normal directo also windy río pierdo boton
# Ofensividad: OFF
# ---------------------------
# Comentario 15856:
# Texto: trump presidente unidos comenzar guerra oriente política anti inmigrante nefasto llegar querés súper muro frontera méxico latino tener culpa merecer
# Ofensividad: OFF
# ---------------------------
# Comentario 15857:
# Texto: atrevser dejar padre cumplan caprichos cobarde delincuent
# Ofensividad: OFF
# ---------------------------
# Comentario 15858:
# Texto: hipocrita ded
# Ofensividad: OFF
# ---------------------------
# Comentario 15859:
# Texto: viejo piruja q amenazar persona huy video dar ganas vomitar
# Ofensividad: OFF
# ---------------------------
# Comentario 15860:
# Texto: maldita señora canival v
# Ofensividad: OFF
# ---------------------------
# Comentario 15861:
# Texto: dejen hablar viejo loca único joder
# Ofensividad: OFF
# ---------------------------
# Comentario 15862:
# Texto: yas putisimo mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 15863:
# ...
# Texto: miren vídeo estúpido fraude xd
# Ofensividad: OFF
# ---------------------------
# Comentario 16584:
# Texto: patético tener venir perfil comentar
# Ofensividad: OFF
# ---------------------------
# Comentario 16585:
# Texto: tonto propuesta
# Ofensividad: OFF
# ---------------------------
# Comentario 16586:
# Texto: jared leto inmortal mierda película
# Ofensividad: OFF
# ---------------------------
# Comentario 16587:
# Texto: bruja lejos tipa nota víbora mentirós manipuladora convenenciera
# Ofensividad: OFF
# ---------------------------
# Comentario 16588:
# Texto: malo poder cosa mala decir q abusador jodio obsesionada chico
# Ofensividad: OFF
# ---------------------------
# Comentario 16589:
# Texto: juan segundo cabron mierda perro wey
# Ofensividad: OFF
# ---------------------------
# Comentario 16590:
# Texto: limpiar imagen mentira ves gente vs cerrar canal ir mesera
# Ofensividad: OFF
# ---------------------------
# Comentario 16591:
# Texto: hijo puta djmario na
# Ofensividad: OFF
# ---------------------------
# Comentario 16592:
# Texto: paola loca mierda listo veiar video amor eterno recién empezar relación hablar pao tener problema internar listo ah
# Ofensividad: OFF
# ---------------------------
# Comentario 16593:
# Texto: subnormal apoyar guitarra puerta alguien
# Ofensividad: OFF
# ---------------------------
# Comentario 16594:
# Texto: maltratador machista manipuladoro agresibar mordedura miare
# Ofensividad: OFF
# ---------------------------
# Comentario 16595:
# Texto: vuelve pringada ah vender yo rollo ser dinero subir video esty descarado entrar sacar yo cuarto reinar
# Ofensividad: OFF
# ---------------------------
# Comentario 16596:
# Texto: odio convirtiesar kilo tendrias atraccion gravitatorial planeta rodeariar piedra gato xdddd
# Ofensividad: OFF
# ---------------------------
# Comentario 16597:
# Texto: tonta sorra
# Ofensividad: OFF
# ---------------------------
# Comentario 16598:
# Texto: ex idea poner novia tenia durar año ver re psicopatir gritar puta telefono ver aceptar haber yo cosa horrible medijo entienden edad juntar compañero colegio año menor juntar universidad trabajar pedazo mierda bronca tratar tiempo haciendome sentir hijo puta
# Ofensividad: OFF
# ---------------------------
# Comentario 16599:
# Texto: pobre yuya esperar pasar demaciar agradable tiernar chica king furio muchisimo asco
# Ofensividad: OFF
# ---------------------------
# Comentario 16600:
# Texto: uffff idiota respeto insultar mono gritir tele pegar gente navaja cani matar refrigerador resumen sayajines mirar luna convertir ozarus dorado cani derrotar freezer ultimo forma gays genkidama puño navajilla cani creyendonos dios destructor universo creer hetero
# Ofensividad: OFF
# ---------------------------
# Comentario 16601:
# Texto: pendejo paty chapoy youtube
# Ofensividad: OFF
# ---------------------------
# Comentario 16602:
# Texto: wismichu cabron haber montar carro raid shadow legends pisito playa pisito playa
# Ofensividad: OFF
# ---------------------------
# Comentario 16603:
# Texto: amiguita miare necesita apoyar públicamente q decia javi game over miare qellar mover dedo ayudar amigo
# Ofensividad: OFF
# ---------------------------
# Comentario 16604:
# Texto: dejar mentir da él sos mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 16605:
# Texto: vecina loca gimnasio seeguro
# Ofensividad: OFF
# ---------------------------
# Comentario 16606:
# Texto: payaso xd
# Ofensividad: OFF
# ---------------------------
# Comentario 16607:
# Texto: hacer puto video mostrar cientos contradicción hundir mierda salir defender cosa dijistir ancho
# Ofensividad: OFF
# ---------------------------
# Comentario 16608:
# Texto: gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 16609:
# Texto: usenme botón jordi tonto ndeah
# Ofensividad: OFF
# ---------------------------
# Comentario 16610:
# Texto: loka estar rato media reinvéntate haztir bypass online hora
# Ofensividad: OFF
# ---------------------------
# Comentario 16611:
# Texto: risa nivel idiot tipa
# Ofensividad: OFF
# ---------------------------
# Comentario 16612:
# Texto: maquillar pringado
# Ofensividad: OFF
# ---------------------------
# Comentario 16613:
# Texto: sentir mostrar cuerpo visita clic bait saber decir ay niño ver vídeo pensar invitar torneo videojuego invitar jugar freir fire gamer ser malo rubiuh
# Ofensividad: OFF
# ---------------------------
# Comentario 16614:
# Texto: notar intentas  copiar creador contenido quedar mem tener humor
# Ofensividad: OFF
# ---------------------------
# Comentario 16615:
# Texto: funaooo funao weon idiota
# Ofensividad: OFF
# ---------------------------
# Comentario 16616:
# Texto: i miss you malditir asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 16617:
# Texto: jajajajaja narutir play imbecil hablar
# Ofensividad: OFF
# ---------------------------
# Comentario 16618:
# Texto: malo persona nisiqueír merés felizidad
# Ofensividad: OFF
# ---------------------------
# Comentario 16619:
# Texto: imbécil asco das uuggghh asco puto cerdo eh asco puto cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 16620:
# Texto: tambeir bloquea gente twitter resultaste cobarde dross
# Ofensividad: OFF
# ---------------------------
# Comentario 16621:
# Texto: convenenciera falsa hipocrita mentirós victimo convenenciero cansarar decir él molestar decir realidad depender persona jugadora ver cuerpo
# Ofensividad: OFF
# ---------------------------
# Comentario 16622:
# Texto: manipuladora dejar mentir molestar darling
# Ofensividad: OFF
# ---------------------------
# Comentario 16623:
# Texto: morra ovario mostrar mierda ovario rectificar
# Ofensividad: OFF
# ---------------------------
# Comentario 16624:
# Texto: mierdo
# Ofensividad: OFF
# ---------------------------
# Comentario 16625:
# Texto: mala
# Ofensividad: OFF
# ---------------------------
# Comentario 16626:
# Texto: pareces bruja
# Ofensividad: OFF
# ---------------------------
# Comentario 16627:
# Texto: cabron tener camiseta bromo bro encantar video
# Ofensividad: OFF
# ---------------------------
# Comentario 16628:
# Texto: illo q feo madre hahahahaha
# Ofensividad: OFF
# ---------------------------
# Comentario 16629:
# Texto: sasel escoria asqueroso poder pasar mundo video juegos fomentandir odio rivalidad comunidad idiota defender creer mierda hablah mentira manipulación pena tipo canal existir uff mendo asco tipo sasel buscar ofender amigo sasel buscar daño interior sasel intención daño tipo despertar
# Ofensividad: OFF
# ---------------------------
# Comentario 16630:
# Texto: mamá loco jodidamente locar ceci ir despedir casa allá reja loca
# Ofensividad: OFF
# ---------------------------
# Comentario 16631:
# Texto: ri pura mierda contenido
# Ofensividad: OFF
# ---------------------------
# Comentario 16632:
# Texto: liberal económicamente sentido diz libre mercado inútil igualmente
# Ofensividad: OFF
# ---------------------------
# Comentario 16633:
# Texto: mierdo dalla
# Ofensividad: OFF
# ---------------------------
# Comentario 16634:
# Texto: patético v
# Ofensividad: OFF
# ---------------------------
# Comentario 16635:
# Texto: tonto viejo pedooo
# Ofensividad: OFF
# ---------------------------
# Comentario 16636:
# Texto: dalas idiota jsjs hater normal internet enogir perder
# Ofensividad: OFF
# ---------------------------
# Comentario 16637:
# Texto: dios penar da imaginar persona engañado ver legua crees personaje ideal diz feliz quítate careta libreeear
# Ofensividad: OFF
# ---------------------------
# Comentario 16638:
# Texto: tipa estúpido serio creer alguien tanto sub dalas afectar pandemia gente casa tiempo entretenimiento virtual youtube público entretener palabra patáticar
# Ofensividad: OFF
# ---------------------------
# Comentario 16639:
# Texto: hijo puta madre mamadisimo
# Ofensividad: OFF
# ---------------------------
# Comentario 16640:
# Texto: dos asco joder gilopolla galaxia sentir pena madre inepto hijo
# Ofensividad: OFF
# ---------------------------
# Comentario 16641:
# Texto: grandiosoooo merecido ridículo
# Ofensividad: OFF
# ---------------------------
# Comentario 16642:
# Texto: qlo feo quedaste pa l pico
# Ofensividad: OFF
# ---------------------------
# Comentario 16643:
# Texto: gordo cuidatar
# Ofensividad: OFF
# ---------------------------
# Comentario 16644:
# Texto: hipócrita cuidado xd
# Ofensividad: OFF
# ---------------------------
# Comentario 16645:
# Texto: nauter cabron pensar foto yt gta
# Ofensividad: OFF
# ---------------------------
# Comentario 16646:
# Texto: mu tonto pillarte
# Ofensividad: OFF
# ---------------------------
# Comentario 16647:
# Texto: comentario familia cárcel jajajaj vergüenza esperar meter cárcel familia xdxd
# Ofensividad: OFF
# ---------------------------
# Comentario 16648:
# Texto: josemi flores caser fatal puto amo
# Ofensividad: OFF
# ---------------------------
# Comentario 16649:
# Texto: jordi hipocrita preguntar da él
# Ofensividad: OFF
# ---------------------------
# Comentario 16650:
# Texto: querer vida falta metar parez hortera ropa gafa preparo abuela
# Ofensividad: OFF
# ---------------------------
# Comentario 16651:
# Texto: cara loca lol
# Ofensividad: OFF
# ---------------------------
# Comentario 16652:
# Texto: miro considerar rutilofila querer sepa entender gustar jp hija quierar decir poder guardartir opinión gustar ver mir vidio gana entender cosa valer túnel viento hija túnel viento gratis barato vue él gustar mir gente gente gustar jod molestar gente seguir apoyar posdata pegar nombre pringada diz madurar madura pinta llevar
# Ofensividad: OFF
# ---------------------------
# Comentario 16653:
# Texto: windy hipocrita
# Ofensividad: OFF
# ---------------------------
# Comentario 16654:
# Texto: falso billete
# Ofensividad: OFF
# ---------------------------
# Comentario 16655:
# Texto: asqueroso gordo feminista gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 16656:
# Texto: tontar tener tiempo chico dejar estudio casarte año jajajajar risto vecino decir error casarte joven sobrar empezar vivir junto convivencia duro ver tener idea quierar parecer chica maduro sentir laura tener experiencia suficiente vida creeme ir equivocar cabo rabo noviazgo vivid junto acabar estudio formate sear madura casais amor deci vida problema cosa salir suerte ir necesitar ojala equivoque perooo
# Ofensividad: OFF
# ---------------------------
# Comentario 16657:
# Texto: puto tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 16658:
# Texto: dinero estúpido dinero cáncer animal peligro extinción cuidadora animal
# Ofensividad: OFF
# ---------------------------
# Comentario 16659:
# Texto: malo persona drede dañar busca ayuda psicológico esperar sea feliz dej feliz
# Ofensividad: OFF
# ---------------------------
# Comentario 16660:
# Texto: señora devir año q feo aruga
# Ofensividad: OFF
# ---------------------------
# Comentario 16661:
# Texto: ir comentario comentar payasa
# Ofensividad: OFF
# ---------------------------
# Comentario 16662:
# Texto: pensar mujer edad avanzado estupidez estupido windy
# Ofensividad: OFF
# ---------------------------
# Comentario 16663:
# Texto: traicionero video
# Ofensividad: OFF
# ---------------------------
# Comentario 16664:
# Texto: we c mmm mmmm mierdar
# Ofensividad: OFF
# ---------------------------
# Comentario 16665:
# Texto: asco gordar hombre practicamente
# Ofensividad: OFF
# ---------------------------
# Comentario 16666:
# Texto: jajajajajaja mirar jpelirrojo formato gusta video blog diario gustar criticar dema tener pinta aceptar critica meter yo grotesco verte expresarte ruido fondo critica insulto digar gym forma fisico video ver gente critica insultar mirar blanco facil decir forma fisico saludable machista pensar machista meter mierda pintada tener brazo vocaliza gafa plastico malo camisa feo lleva recordar grotesco agatha ruiz prado opinión penoso trist simplemente grotesco
# Ofensividad: OFF
# ---------------------------
# Comentario 16667:
# Texto: recuerdo soler mirar puto pensar malo mirenlo
# Ofensividad: OFF
# ---------------------------
# Comentario 16668:
# Texto:
# Ofensividad: OFF
# ---------------------------
# Comentario 16669:
# Texto: bruja cochín
# Ofensividad: OFF
# ---------------------------
# Comentario 16670:
# Texto: jajajajar denunciar banear estupida ojalá banear internet completo
# Ofensividad: OFF
# ---------------------------
# Comentario 16671:
# Texto: windi prosti
# Ofensividad: OFF
# ---------------------------
# Comentario 16672:
# Texto: tipar enferma
# Ofensividad: OFF
# ---------------------------
# Comentario 16673:
# Texto: hijo puta leer voz video
# Ofensividad: OFF
# ---------------------------
# Comentario 16674:
# Texto: subir video crítica kimberly twitch seguir él hablar dejar seguidor anda lame bota objetivir
# Ofensividad: OFF
# ---------------------------
# Comentario 16675:
# Texto: gordo valla ver gordar x gordar x nizar
# Ofensividad: OFF
# ---------------------------
# Comentario 16676:
# Texto: pintar gay tener
# Ofensividad: OFF
# ---------------------------
# Comentario 16677:
# Texto: oir pringado observar desprecio madre entender
# Ofensividad: OFF
# ---------------------------
# Comentario 16678:
# Texto: valla pendejar hecho
# Ofensividad: OFF
# ---------------------------
# Comentario 16679:
# Texto: deír montón risa tiempo enojo dejar llanto vídeo pudiendolo editar tipar mentirosa
# Ofensividad: OFF
# ---------------------------
# Comentario 16680:
# Texto: estupido mierda caser
# Ofensividad: OFF
# ---------------------------
# Comentario 16681:
# Texto: responder payaso aparecer video xd uwu
# Ofensividad: OFF
# ---------------------------
# Comentario 16682:
# Texto: mierda gustar
# Ofensividad: OFF
# ---------------------------
# Comentario 16683:
# Texto: gordar eeeee paso va caber puerta joderr
# Ofensividad: OFF
# ---------------------------
# Comentario 16684:
# Texto: soyunapringada crecer adolescente ñoña cursi año pasar volar pata gallo treintañera acabado llegar seguida vídeo youtube ver año dentera
# Ofensividad: OFF
# ---------------------------
# Comentario 16685:
# Texto: tio puta gordar gorda jodir grito decir encantar v
# Ofensividad: OFF
# ---------------------------
# Comentario 16686:
# Texto: súper mega uñtra recontrar hiper mamado hijo puta
# Ofensividad: OFF
# ---------------------------
# Comentario 16687:
# Texto: payaso turbo
# Ofensividad: OFF
# ---------------------------
# Comentario 16688:
# Texto: ratera mitómana mnipuladora ardida
# Ofensividad: OFF
# ---------------------------
# Comentario 16689:
# Texto: nazi
# Ofensividad: OFF
# ---------------------------
# Comentario 16690:
# Texto: dawn mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 16691:
# Texto: perra asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 16692:
# Texto: argo falsa dejar mentir
# Ofensividad: OFF
# ---------------------------
# Comentario 16693:
# Texto: puto calvo tonto
# Ofensividad: OFF
# ---------------------------
# Comentario 16694:
# Texto: k ridículo k va cárcel
# Ofensividad: OFF
# ---------------------------
# Comentario 16695:
# Texto: re fachaber nauter
# Ofensividad: OFF
# ---------------------------
# Comentario 16696:
# Texto: dalas pendejo
# Ofensividad: OFF
# ---------------------------
# Comentario 16697:
# Texto: cuarto video miare soportado puta zorra
# Ofensividad: OFF
# ---------------------------
# Comentario 16698:
# Texto: estupidar
# Ofensividad: OFF
# ---------------------------
# Comentario 16699:
# Texto: weon feo
# Ofensividad: OFF
# ---------------------------
# Comentario 16700:
# Texto: joputa meter cárcel
# Ofensividad: OFF
# ---------------------------
# Comentario 16701:
# Texto: tonto nombresito video menor edad ver
# Ofensividad: OFF
# ---------------------------
# Comentario 16702:
# Texto: pregunta gilipol él entrenar
# Ofensividad: OFF
# ---------------------------
# Comentario 16703:
# Texto: estás gordo
# Ofensividad: OFF
# ---------------------------
# Comentario 16704:
# Texto: verguenzo ajena like crees windy retrasado
# Ofensividad: OFF
# ---------------------------
# Comentario 16705:
# Texto: estar locar daño
# Ofensividad: OFF
# ---------------------------
# Comentario 16706:
# Texto: hijo puta madre mamadisimo
# Ofensividad: OFF
# ---------------------------
# Comentario 16707:
# Texto: año ver dar mierda grefg
# Ofensividad: OFF
# ---------------------------
# Comentario 16708:
# Texto: re blanco wismi
# Ofensividad: OFF
# ---------------------------
# Comentario 16709:
# Texto: ver botella rosado seguramente lleno champaña hacer imaginar imagen directo windy sentado asiento inflable infla windy globo vean directo windy engordar heladera seguro dulce chocolate tamaño color
# Ofensividad: OFF
# ---------------------------
# Comentario 16710:
# Texto: ballena
# Ofensividad: OFF
# ---------------------------

# %%
from sklearn.metrics import f1_score, recall_score

# %%
from sklearn import svm

# %%
texto_comentarios_dev = []
ofensividad_comentarios_dev = []

# Recorrer los comentarios y guardar la información en las listas
for comentario in comentarios_dev:
    texto_comentarios_dev.append(comentario['texto'])
    ofensividad_comentarios_dev.append(comentario['ofensividad'])

# Comprobar que las listas tienen el mismo tamaño
assert len(texto_comentarios_dev) == len(ofensividad_comentarios_dev), "Las listas tienen diferente tamaño"

# Imprimir un ejemplo
for i in range(len(texto_comentarios_dev)):
    print(f"Comentario {i + 1}:")
    print(f"Texto: {texto_comentarios_dev[i]}")
    print(f"Ofensividad: {ofensividad_comentarios_dev[i]}")
    print("---------------------------")
# Out:
# Comentario 1:
# Texto: encantar videooo porciento aidii subir video poder ver él porfiii costar editar él esperar gustar ojala veas tequieroooo
# Ofensividad: NON
# ---------------------------
# Comentario 2:
# Texto: ropa dulceida shop zara forma ésto lookbook hacertir idea estilo adaptar él único caro bolso prada comprar mango apaño crítica crítica sobrar
# Ofensividad: NON
# ---------------------------
# Comentario 3:
# Texto: perra seguia v
# Ofensividad: OFF
# ---------------------------
# Comentario 4:
# Texto: malditas droga
# Ofensividad: NON
# ---------------------------
# Comentario 5:
# Texto: perdonar spam tratar poner yo contacto youtuber tratar hacer yo escuchar idiota encantariar hablar vos forma pacifico gustario aconsejarte gustariar decirtir mejorar imagen deberia diferencia d elo dema argumento
# Ofensividad: NON
# ---------------------------
# Comentario 6:
# Texto: encantar vídeo sigue ver feliz relajado abierto punto encantar ola
# Ofensividad: NON
# ---------------------------
# Comentario 7:
# Texto: estar subir videoreacción pusieros original descripción apoyar creador contenido
# Ofensividad: NON
# ---------------------------
# Comentario 8:
# Texto: señorita favor hacer contenido heducativo deje mostrar cuerpo ganar likesssss favor llegar pena
# Ofensividad: OFF
# ---------------------------
# Comentario 9:
# Texto: espabila coño
# Ofensividad: NON
# ---------------------------
# Comentario 10:
# Texto: chica estar feo
# Ofensividad: OFF
# ---------------------------
# Comentario 11:
# Texto: lastimo fan saber razonar lógico obvio porqué pón condición huevo aceptar él seguro ganar debate acobardacer hacer
# Ofensividad: NON
# ---------------------------
# Comentario 12:
# Texto: fresca joven libre
# Ofensividad: NON
# ---------------------------
# Comentario 13:
# Texto: javi dile editor normalizar nivel sonido voz efecto transción sonar super fuerte quedar
# Ofensividad: NON
# ---------------------------
# Comentario 14:
# Texto: it original dar peli
# Ofensividad: NON
# ---------------------------
# Comentario 15:
# Texto: vídeo dijistir jpelirrojo horror video debate discusión dallas jp parecerme repulsivo dallas listo correcto maduro persona vergüenza ajena
# Ofensividad: OFF
# ---------------------------
# Comentario 16:
# Texto: podrar wismishu podrar año f f chat enantar seccion
# Ofensividad: NON
# ---------------------------
# Comentario 17:
# Texto: tanto comentario negativos dejar vivir coño
# Ofensividad: NON
# ---------------------------
# Comentario 18:
# Texto: dalaw cobrar vídeo palabra prohibido decir juan rato
# Ofensividad: NON
# ---------------------------
# Comentario 19:
# Texto: wismichu puto amar siglos siglos amen
# Ofensividad: NON
# ---------------------------
# Comentario 20:
# Texto: amor respeto sexo género color piel etc vivir amor igualdad fueraaar odiooooo
# Ofensividad: NON
# ---------------------------
# Comentario 21:
# Texto: uf alejar cara tanto grasa ver estresser venir hombre opresor blanco ballenero pensado
# Ofensividad: OFF
# ---------------------------
# Comentario 22:
# Texto: diós crush to dios sobrevalorado realmente endiosar sinceramente nivel maría pedraza repercusión ester lejos realmente mujer increíble poder llegar ofendidito criticar conocer gente pensar ester increíble contrario miedo echar
# Ofensividad: NON
# ---------------------------
# Comentario 23:
# Texto: hola jp pequeño admiradora año ver concierto sala galileo galilei cancion encantar
# Ofensividad: NON
# ---------------------------
# Comentario 24:
# Texto: khalifa enserio decir
# Ofensividad: NON
# ---------------------------
# Comentario 25:
# Texto: ver sepa fútbol pobre reguilon recibir tremendo bullying ajax partido barça
# Ofensividad: NON
# ---------------------------
# Comentario 26:
# Texto: des explicación subes video simplemente subas favor harías favor mundial perdedor inútil
# Ofensividad: OFF
# ---------------------------
# Comentario 27:
# Texto: visualización aconsejar gente matar él encontrar psicólogo tia consciente gente ver sueltir boca coherente
# Ofensividad: OFF
# ---------------------------
# Comentario 28:
# Texto: dala podrías lizy video subtitulo desastroso youtube video locutor perro subtitulado poner pirri video horribl
# Ofensividad: NON
# ---------------------------
# Comentario 29:
# Texto: so hermoso v m p i r
# Ofensividad: NON
# ---------------------------
# Comentario 30:
# Texto: jajaja epico dalas review hacer video windy amiga liar
# Ofensividad: NON
# ---------------------------
# Comentario 31:
# Texto: probabilidad nulo costar participar gustar premio aburrido casa
# Ofensividad: NON
# ---------------------------
# Comentario 32:
# Texto: t l r n c i gracias ayudar analicir cuestionen forma pensar romper esquema mente retrógrado ayudar sentar sentir forma pensar rodear maltratar psicológicamente marcar rumbo vida complicado resumo respeto tolerancia alguien sentir inferior sentir siéntete pensar sentir cuento haber perder aceptar pretender abrelosojo
# Ofensividad: NON
# ---------------------------
# Comentario 33:
# Texto: crítica constructivo repetitivo tema expresión opinión aprovechar contenido canal
# Ofensividad: NON
# ---------------------------
# Comentario 34:
# Texto: crítica constructivo jajar quieres likes atención cualquiera dar jugar dalar oportunidad jugar mejor chica jugar querer lugar necesitar mostrar cuerpo necesitos dinero trabajo poder ganar poder barato querer mostrar cuerpo tanto cosa trabajo ideal crítico heroico temporada año jugar nadama decir saludo jiji
# Ofensividad: OFF
# ---------------------------
# Comentario 35:
# Texto: cuarentena esperar maaajaa cuelgues vídeo hacer yo él fácil estás entretenido jajajajajar ahhh oy esperar hagar hablar serie veneno fantasía
# Ofensividad: NON
# ---------------------------
# Comentario 36:
# Texto: dalaaaaaaaaaaaaaaaas interesar jukikk interesado mundo vivir abajo mundo arder sigues  subir video farándula jajaj
# Ofensividad: NON
# ---------------------------
# Comentario 37:
# Texto: dalas town pedo inforte has video gente volvera  loca
# Ofensividad: NON
# ---------------------------
# Comentario 38:
# Texto: oír hablar wanda venir mente padrino mágico jajajajajaja
# Ofensividad: NON
# ---------------------------
# Comentario 39:
# Texto: felicidad soportar año mierda
# Ofensividad: NON
# ---------------------------
# Comentario 40:
# Texto: collar hija fan
# Ofensividad: NON
# ---------------------------
# Comentario 41:
# Texto: chica tomar video tomar molestia ver él hora directo recopilar información preciso vago agarra estracto directamente tomar molestia editar cosa llamar trabajo deber soltar semejante argumento vago español chulito persona vídeo ende haya visto hora directo persona haya editado trabajado tomar material haber currar tomar yo molestia hora hora directo vago facil digar pesada dejar soplagaita dale credito
# Ofensividad: OFF
# ---------------------------
# Comentario 42:
# Texto: jajajajajajaja flipar cuenta historia normal pasar diario señora pringada subir vídeo historia diooos necesitar sentir yo vivo jejejar  saludo
# Ofensividad: NON
# ---------------------------
# Comentario 43:
# Texto: viejo interezar arreglar cosa canal base puesta juan sintio ala quacer volar haciendolos quedar malagradecida envidiós mordio mano comer notar aliado persona daño caso zorro seguir dios bendecir
# Ofensividad: OFF
# ---------------------------
# Comentario 44:
# Texto: entender hechaber tanto mierda da él ganar
# Ofensividad: NON
# ---------------------------
# Comentario 45:
# Texto: necesario hagar clase video llegar tanto gente súper joven respeto hacer avanzar retroceder
# Ofensividad: NON
# ---------------------------
# Comentario 46:
# Texto: vídeo odio amor poeta odiar amar
# Ofensividad: NON
# ---------------------------
# Comentario 47:
# Texto: celoso pq jp gym caminar
# Ofensividad: NON
# ---------------------------
# Comentario 48:
# Texto: dalas gustar bro gente juzgar
# Ofensividad: NON
# ---------------------------
# Comentario 49:
# Texto: subir vídeo mundo hipocritar da lamento pensar contrario diz mentira dañar crear polémica queda youtubers haber mencionar criticar ser rencoroso canal haber ir ofender entender clipvey video subir contenido original actualízatir freefirar listo desahogar like pensar
# Ofensividad: OFF
# ---------------------------
# Comentario 50:
# Texto: recordar ví video teoría secta travestis osea palabra textual secta travesti recuerdo
# Ofensividad: NON
# ---------------------------
# Comentario 51:
# Texto: notar may color pelo dalas lizy color lol v
# Ofensividad: NON
# ---------------------------
# Comentario 52:
# Texto: che re falso entender dar alimento heitesr osea ignoralos
# Ofensividad: NON
# ---------------------------
# Comentario 53:
# Texto: hablasteis volver fotolog foto video poneis acordar estalle fallo tecnico show gijon
# Ofensividad: NON
# ---------------------------
# Comentario 54:
# Texto: dalas va salir pambisito corazón apoyar momento muchísimo suerte
# Ofensividad: NON
# ---------------------------
# Comentario 55:
# Texto: luchuga subnormal tipo luchuga
# Ofensividad: OFF
# ---------------------------
# Comentario 56:
# Texto: mirey querer tipo derecho insultar él dueña vida querer dejar estupidez quiero follarmela querer verte desnuda etc sear mirey quieretar favor recordar mujer deber tratar amor delicadeza respetar chica mujer gustar tratar hermana mamá sear quieretir favor besito tomen awuita salgan casas favor
# Ofensividad: OFF
# ---------------------------
# Comentario 57:
# Texto: javi aligual belen esteban familia español familia lejos pasar erte crisis coronavirus salimos público aplaudar llevar secreto salir jorge javier enfado político enfado belén tachar jorge javier vivir vivir jorge javier mundo tener familia situación económico normal familia erte enfado ver normal situación país decir alguien opinión distinto opinión vivir coronavirus hipócrita
# Ofensividad: NON
# ---------------------------
# Comentario 58:
# Texto: dalar maldito crédito
# Ofensividad: NON
# ---------------------------
# Comentario 59:
# Texto: totalmente momento regresar opinion da él alguien dejar espejo
# Ofensividad: NON
# ---------------------------
# Comentario 60:
# Texto: cerdo
# Ofensividad: OFF
# ---------------------------
# Comentario 61:
# Texto: retrasar
# Ofensividad: OFF
# ---------------------------
# Comentario 62:
# Texto: conocido hermano autismo problema superpoder lastima padre maravilloso hijo teniar
# Ofensividad: NON
# ---------------------------
# Comentario 63:
# Texto: mirar miare entender juego pedir entiednda titulo pensar vejete simpsons cantado
# Ofensividad: NON
# ---------------------------
# Comentario 64:
# Texto: poner plan tendríar pedir él grefg devolver dinero ganar base creación juego jugar
# Ofensividad: NON
# ---------------------------
# Comentario 65:
# Texto: poder reclamar contenido tomar video secret net marca agua reclamar él dueña cara miare adivinir secretnet valla estupidez defender estúpido contenido ver directo recorte seguir miare
# Ofensividad: OFF
# ---------------------------
# Comentario 66:
# Texto: adicciones mania trauma carencia emocional tener propondriar adelgazar sano cabeza empezar sano fisicamente
# Ofensividad: OFF
# ---------------------------
# Comentario 67:
# Texto: poder mensaje directo app hazlo sorpresa tributo
# Ofensividad: NON
# ---------------------------
# Comentario 68:
# Texto: importar soltero vida referencia
# Ofensividad: NON
# ---------------------------
# Comentario 69:
# Texto: jajaja llamar pato lucas latinoamérica xd
# Ofensividad: NON
# ---------------------------
# Comentario 70:
# Texto: euros euros invitar copa lleva mano
# Ofensividad: NON
# ---------------------------
# Comentario 71:
# Texto: daño acer pequeño ojalá recuperar trauma causado monstruo quitario hijo merecer padre hijo dar problema hacer
# Ofensividad: NON
# ---------------------------
# Comentario 72:
# Texto: psssss pssss windy venir decirte ninja caso estupido tweet xd caso
# Ofensividad: OFF
# ---------------------------
# Comentario 73:
# Texto: windy fan admirar inter ayudar necesidad pón imagen portada video osea importir mirar cuerpo importir mirar corazón
# Ofensividad: NON
# ---------------------------
# Comentario 74:
# Texto: wismichu usar cortina abuela camisa desviar atención calvicie volver hipster destiempo querer reavivar subcultura puto calvo starter pack
# Ofensividad: OFF
# ---------------------------
# Comentario 75:
# Texto: exactamente ver recomendación decidir probar él inversión obtener feliz invertir forex
# Ofensividad: NON
# ---------------------------
# Comentario 76:
# Texto: necesitar porfavor podría centrartir tema detallar él poder interesar muchísimo gracias
# Ofensividad: NON
# ---------------------------
# Comentario 77:
# Texto: vergüenza sentir defender haber demostrar mil imbécil saber superar ruptura persona normal aprovechar tumor joderte crecer hijo esperar venir hacer él sufrir creer ánimo karma devolver carrera terminado adoramos verte humor presencia dej caer vida escalón avanza mañana retroced
# Ofensividad: OFF
# ---------------------------
# Comentario 78:
# Texto: persona youtube like año carcel persona asqueroso
# Ofensividad: OFF
# ---------------------------
# Comentario 79:
# Texto: encantar canción ser sincero canción sobrepasar sentir vivo encantar llenar corazón
# Ofensividad: NON
# ---------------------------
# Comentario 80:
# Texto: gustar video sacar relucir negativo querer casar año tema enamorado discutir él hacer vida privado gustar video haber colocar rellenar llegar min esperar tom crítica destructivo
# Ofensividad: NON
# ---------------------------
# Comentario 81:
# Texto: flipar vídeo risa hechar vídeo súper parecida guapísimar alex querer vídeo alex porfa
# Ofensividad: NON
# ---------------------------
# Comentario 82:
# Texto: dejen reseña video depresiva gordita gamer chingadamadre gamer gamer depresiva acaso decir gamer depresiva gamer
# Ofensividad: OFF
# ---------------------------
# Comentario 83:
# Texto: violador mierda
# Ofensividad: OFF
# ---------------------------
# Comentario 84:
# Texto: joder guarrar otaku
# Ofensividad: OFF
# ---------------------------
# Comentario 85:
# Texto: público mina pibes pajero año gente venir alimentar él cringe wna
# Ofensividad: OFF
# ---------------------------
# Comentario 86:
# Texto: salseo nauter secret net seccion canal dar palo cuadrilatero disfrutar palomita
# Ofensividad: NON
# ---------------------------
# Comentario 87:
# Texto: maria esperar hayas sentido creciste pasaste atravez ojala pudierar volver ejerce yo enseñanza violento amoroso hahahahir
# Ofensividad: NON
# ---------------------------
# Comentario 88:
# Texto: olé coño apetecer subir sobar estar obligado olé olé
# Ofensividad: NON
# ---------------------------
# Comentario 89:
# Texto: año perra seguia seguia
# Ofensividad: OFF
# ---------------------------
# Comentario 90:
# Texto: estar guay jugara seguidor discord discord vip da él seriar gesto bonito tendría contenido canal videojuego
# Ofensividad: NON
# ---------------------------
# Comentario 91:
# Texto: miare persona admirable aguantar aguantar mierda echais mantener él fuerte importar comentario mundo capaz
# Ofensividad: NON
# ---------------------------
# Comentario 92:
# Texto: mem windy hater gente querer divertir
# Ofensividad: NON
# ---------------------------
# Comentario 93:
# Texto: encanta lau gustar asii super fresco elegancia natural tuyaao uffff
# Ofensividad: NON
# ---------------------------
# Comentario 94:
# Texto: momento tema negar jordi estrategia servir
# Ofensividad: NON
# ---------------------------
# Comentario 95:
# Texto: entender malinterpretar hombre mujer simple mente quedar visto foto sal súper depilado ostia ipocrita
# Ofensividad: NON
# ---------------------------
# Comentario 96:
# Texto: alegrar da él seguidor alegrar alguien ocultar mienta ver super natural ser nacimiento saludo ecuador recuperare
# Ofensividad: NON
# ---------------------------
# Comentario 97:
# Texto: resumen dala callo puta boco
# Ofensividad: NON
# ---------------------------
# Comentario 98:
# Texto: genial llevar alcaser caras belmez camping alfaques
# Ofensividad: NON
# ---------------------------
# Comentario 99:
# Texto: hola da él querer sepáis tener apoyo pasar pasar servir noticia público historia instagram ayudo viral persona estar pasar pasar contarás necesit dar opinión tema indignante poder cariño tener bello mujer amar apoyar suscriptor prácticamente vida apoyar cansar youtuber favorito serás pasar pasar tenéis apoyo ayudar amar
# Ofensividad: NON
# ---------------------------
# Comentario 100:
# Texto: crees polemico muestra escote cansar mitad subs haters pón título doble sentido
# Ofensividad: NON
# ---------------------------

# %% [markdown]
# ### No supervisado (K means)

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# %%
k = 2
model = KMeans(n_clusters=k)
model.fit(X) # entrenamiento
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()
for i in range(k):
  print("\nCluster:", i)
  for ind in order_centroids[i, :50]:
    print(' \t', terms[ind])
# Out:
# Top terms per cluster:
#
# Cluster: 0
#  	 video
#  	 ver
#  	 él
#  	 vídeo
#  	 dalas
#  	 gente
#  	 persona
#  	 gustar
#  	 querer
#  	 xd
#  	 decir
#  	 encantar
#  	 cosa
#  	 pasar
#  	 puto
#  	 año
#  	 tener
#  	 windy
#  	 haber
#  	 canal
#  	 vida
#  	 pensar
#  	 seguir
#  	 esperar
#  	 dejar
#  	 dar
#  	 quedar
#  	 foto
#  	 hacer
#  	 hablar
#  	 malo
#  	 salir
#  	 gracias
#  	 poner
#  	 alguien
#  	 saludo
#  	 puta
#  	 youtube
#  	 poder
#  	 subir
#  	 comentario
#  	 mundo
#  	 estar
#  	 dala
#  	 entender
#  	 amar
#  	 javi
#  	 tiempo
#  	 sentir
#  	 chica
#
# Cluster: 1
#  	 mierda
#  	 video
#  	 cacho
#  	 canal
#  	 él
#  	 gente
#  	 vida
#  	 vídeo
#  	 subir
#  	 dalas
#  	 persona
#  	 dejar
#  	 mundo
#  	 ver
#  	 querer
#  	 puta
#  	 ir
#  	 puto
#  	 gustar
#  	 tirar
#  	 tener
#  	 encantar
#  	 importar
#  	 haber
#  	 fan
#  	 sos
#  	 miare
#  	 cosa
#  	 hola
#  	 peli
#  	 gracias
#  	 caer
#  	 youtuber
#  	 youtube
#  	 xd
#  	 amar
#  	 cara
#  	 extrañar
#  	 entender
#  	 dar
#  	 pensar
#  	 real
#  	 decir
#  	 contenido
#  	 asco
#  	 sentir
#  	 gana
#  	 da
#  	 sacar
#  	 tanto

# %%
##############################EVALUACIÓN DE ENTRENAMIENTO NO SUPERVISADO##############################
# Asumiendo que 'texto_comentarios_dev' y 'ofensividad_comentario_dev' son los datos de desarrollo

# Inicializar contador de aciertos
aciertos = 0

# Recorrer los datos de desarrollo y realizar las predicciones
for i, comentario in enumerate(texto_comentarios_dev):
    Y = vectorizer.transform([comentario])
    prediction = model.predict(Y)
    
    # Comparar la predicción con la etiqueta real de ofensividad
    cluster=0
    if ofensividad_comentarios_dev[i]=="OFF":
      cluster=1
    if prediction[0] == cluster:
        aciertos += 1
    
    # Imprimir el comentario, la predicción y la etiqueta real de ofensividad
    #print(f"Comentario: {comentario}")
    #print(f"Predicción: {prediction[0]}")
    #print(f"Etiqueta real: {ofensividad_comentarios_dev[i]}")
    #print("---------------------------")

# Calcular la precisión
precision = aciertos / len(texto_comentarios_dev)

# Imprimir la precisión
print(f"Precisión: {precision}")
# Out:
# Precisión: 0.72

# %% [markdown]
# # Nueva sección

# %% [markdown]
# ### Función Para Medir Precisión de los supervisados

# %%
from sklearn.metrics import classification_report

def calculaPrecision(vectorizer,modelo):
  # Asumiendo que 'texto_comentarios_dev' y 'ofensividad_comentario_dev' son los datos de desarrollo

  # Inicializar contador de aciertos
  aciertos = 0

  predictions = []

  # Recorrer los datos de desarrollo y realizar las predicciones
  for i, comentario in enumerate(texto_comentarios_dev):
    Y = vectorizer.transform([comentario])
    prediction = modelo.predict(Y)
    predictions.append(prediction[0])
    
    # Comparar la predicción con la etiqueta real de ofensividad
    if prediction[0] == ofensividad_comentarios_dev[i]:
        aciertos += 1
    
    # Imprimir el comentario, la predicción y la etiqueta real de ofensividad
    #print(f"Comentario: {comentario}")
    #print(f"Predicción: {prediction[0]}")
    #print(f"Etiqueta real: {ofensividad_comentarios_dev[i]}")
    #print("---------------------------")

  # Calcular la precisión
  precision = aciertos / len(texto_comentarios_dev)

  # Imprimir la precisión
  print(f"Precisión: {precision}")
  print(f"Macro-f1", f1_score(ofensividad_comentarios_dev, predictions, average='macro'))
  print(f"Recall", recall_score(ofensividad_comentarios_dev, predictions, average='macro'))
  report = classification_report(ofensividad_comentarios_dev, predictions)
  print(report)

# %% [markdown]
# SVM

# %%
print("Muestro comentario trainig: ", texto_comentarios_training[0], " y su etiqueta: ", ofensividad_comentarios_training[0])
print("Muestro comentario dev: ", texto_comentarios_dev[0], " y su etiqueta: ", ofensividad_comentarios_dev[0])
print("Muestro comentario test: ", comentarios_test[0]["texto"])
# Out:
# Muestro comentario trainig:  magia melena magia nariz xd  y su etiqueta:  NON
# Muestro comentario dev:  encantar videooo porciento aidii subir video poder ver él porfiii costar editar él esperar gustar ojala veas tequieroooo  y su etiqueta:  NON
# Muestro comentario test:  lacasito moreno

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# %%
model = svm.SVC()
model.fit(X, ofensividad_comentarios_training)
# Out:
# SVC()

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.79
# Macro-f1 0.5991601450658524
# Recall 0.5961538461538461
#               precision    recall  f1-score   support
#
#          NON       0.78      1.00      0.88        74
#          OFF       1.00      0.19      0.32        26
#
#     accuracy                           0.79       100
#    macro avg       0.89      0.60      0.60       100
# weighted avg       0.84      0.79      0.73       100

# %% [markdown]
# ### Supervisado ( Naive Bayes )

# %%
#SUPERVISADO CON NAIVE BAYES
from sklearn.naive_bayes import MultinomialNB
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)
clf = MultinomialNB(alpha=0)
clf.fit(X, ofensividad_comentarios_training)
#model = svm.SVC()
#model.fit(X, ofensividad_comentarios_training)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# MultinomialNB(alpha=0)

# %%
calculaPrecision(vectorizer,clf)
# Out:
# Precisión: 0.78
# Macro-f1 0.627371273712737
# Recall 0.6143451143451143
#               precision    recall  f1-score   support
#
#          NON       0.79      0.96      0.87        74
#          OFF       0.70      0.27      0.39        26
#
#     accuracy                           0.78       100
#    macro avg       0.74      0.61      0.63       100
# weighted avg       0.77      0.78      0.74       100

# %% [markdown]
# ### Supervisado ( SVM con lexicon)

# %% [markdown]
# Enlace Lexicón: https://sinai.ujaen.es/index.php/investigacion/recursos/share-lexicon-de-expresiones-ofensivas-de-la-poblacion-espanola

# %%
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training + elementosLexicon)

model = svm.SVC()
model.fit(X, ofensividad_comentarios_training+etiquetasLexicon)
# Out:
# SVC()

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.78
# Macro-f1 0.627371273712737
# Recall 0.6143451143451143
#               precision    recall  f1-score   support
#
#          NON       0.79      0.96      0.87        74
#          OFF       0.70      0.27      0.39        26
#
#     accuracy                           0.78       100
#    macro avg       0.74      0.61      0.63       100
# weighted avg       0.77      0.78      0.74       100

# %% [markdown]
# ### Supervisado (Arboles decision )

# %%
#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.79
# Macro-f1 0.6778647031753336
# Recall 0.6585239085239085
#               precision    recall  f1-score   support
#
#          NON       0.81      0.93      0.87        74
#          OFF       0.67      0.38      0.49        26
#
#     accuracy                           0.79       100
#    macro avg       0.74      0.66      0.68       100
# weighted avg       0.77      0.79      0.77       100

# %% [markdown]
# ### Probando vectorizer CountVectorizer

# %% [markdown]
# Primer mejor

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.84
# Macro-f1 0.7588908981314044
# Recall 0.7297297297297297
#               precision    recall  f1-score   support
#
#          NON       0.85      0.96      0.90        74
#          OFF       0.81      0.50      0.62        26
#
#     accuracy                           0.84       100
#    macro avg       0.83      0.73      0.76       100
# weighted avg       0.84      0.84      0.83       100

# %% [markdown]
# Primer mejor con lexicon

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training+elementosLexicon)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training+etiquetasLexicon)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.72
# Macro-f1 0.5257452574525745
# Recall 0.5363825363825364
#               precision    recall  f1-score   support
#
#          NON       0.76      0.92      0.83        74
#          OFF       0.40      0.15      0.22        26
#
#     accuracy                           0.72       100
#    macro avg       0.58      0.54      0.53       100
# weighted avg       0.66      0.72      0.67       100

# %% [markdown]
# ### Probando vectorizer HashingVectorizer

# %% [markdown]
# Tercer mejor

# %%
from sklearn.feature_extraction.text import HashingVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer3 = HashingVectorizer()
X = vectorizer3.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
modelDTHV = DecisionTreeClassifier(random_state=42)
modelDTHV.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
calculaPrecision(vectorizer3,modelDTHV)
# Out:
# Precisión: 0.77
# Macro-f1 0.647185151096794
# Recall 0.6325363825363826
#               precision    recall  f1-score   support
#
#          NON       0.80      0.92      0.86        74
#          OFF       0.60      0.35      0.44        26
#
#     accuracy                           0.77       100
#    macro avg       0.70      0.63      0.65       100
# weighted avg       0.75      0.77      0.75       100

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Utilizar Regresión Logística en lugar de MultinomialNB
clf = LogisticRegression(max_iter=1000)

clf.fit(X, ofensividad_comentarios_training)
# Out:
# LogisticRegression(max_iter=1000)

# %%
calculaPrecision(vectorizer,clf)
# Out:
# Precisión: 0.78
# Macro-f1 0.5686274509803921
# Recall 0.5769230769230769
#               precision    recall  f1-score   support
#
#          NON       0.77      1.00      0.87        74
#          OFF       1.00      0.15      0.27        26
#
#     accuracy                           0.78       100
#    macro avg       0.89      0.58      0.57       100
# weighted avg       0.83      0.78      0.71       100

# %% [markdown]
# Segundo mejor

# %%
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
import csv

# Crear el vectorizador
vectorizer2 = TfidfVectorizer()
X_train_vectorized = vectorizer2.fit_transform(texto_comentarios_training)
X_dev_vectorized = vectorizer2.transform(texto_comentarios_dev)

# Entrenar el modelo SVM
modelSVMTfidf = svm.SVC(C=1, kernel='linear', gamma='scale')
modelSVMTfidf.fit(X_train_vectorized, ofensividad_comentarios_training)

# Realizar las predicciones en el conjunto de desarrollo
y_pred = modelSVMTfidf.predict(X_dev_vectorized)

# %%
calculaPrecision(vectorizer2,modelSVMTfidf)
# Out:
# Precisión: 0.81
# Macro-f1 0.6552349845763019
# Recall 0.6346153846153846
#               precision    recall  f1-score   support
#
#          NON       0.80      1.00      0.89        74
#          OFF       1.00      0.27      0.42        26
#
#     accuracy                           0.81       100
#    macro avg       0.90      0.63      0.66       100
# weighted avg       0.85      0.81      0.77       100

# %% [markdown]
# Pruebas con test

# %% [markdown]
# Primer mejor

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### Juntar a los tres mejores

# %%
def juntaPredicciones(modelo1,vectorizer1,modelo2,vectorizer2,modelo3,vectorizer3):
    predictions=[]
    aciertos=[]
    for i, comentario in enumerate(texto_comentarios_dev):
      Y = vectorizer1.transform([comentario])
      prediction1 = modelo1.predict(Y)
      Y = vectorizer2.transform([comentario])
      prediction2 = modelo2.predict(Y)
      Y = vectorizer3.transform([comentario])
      prediction3 = modelo3.predict(Y)
      #print(prediction3[0])
      votaciones = [prediction1[0], prediction2[0], prediction3[0]] #elegimos la mas votada
      #votaciones = [prediction1[0], prediction1[0],prediction2[0], prediction3[0]] # le damos mas peso al mejor
      #votaciones = [prediction1[0],prediction2[0]] # los dos mejores
      prediction = max(set(votaciones), key=votaciones.count)
      #print(prediction)
      predictions.append(prediction)

       # Comparar la predicción con la etiqueta real de ofensividad
      #if prediction == ofensividad_comentarios_dev[i]:
        #aciertos += 1
    
      # Imprimir el comentario, la predicción y la etiqueta real de ofensividad
      #print(f"Comentario: {comentario}")
      #print(f"Predicción: {prediction[0]}")
      #print(f"Etiqueta real: {ofensividad_comentarios_dev[i]}")
      #print("---------------------------")

    # Calcular la precisión
    #precision = aciertos / len(texto_comentarios_dev)

    # Imprimir la precisión
    #print(f"Precisión: {precision}")
    print(f"Macro-f1", f1_score(ofensividad_comentarios_dev, predictions, average='macro'))
    print(f"Recall", recall_score(ofensividad_comentarios_dev, predictions, average='macro'))
    report = classification_report(ofensividad_comentarios_dev, predictions)
    print(report)

    

juntaPredicciones(model,vectorizer,modelSVMTfidf,vectorizer2,modelDTHV,vectorizer3)
# Out:
# Macro-f1 0.6849610346542863
# Recall 0.6595634095634095
#               precision    recall  f1-score   support
#
#          NON       0.81      0.97      0.88        74
#          OFF       0.82      0.35      0.49        26
#
#     accuracy                           0.81       100
#    macro avg       0.81      0.66      0.68       100
# weighted avg       0.81      0.81      0.78       100

# %% [markdown]
# ### Probando red neuronal (tarda 25 minutos) la de 100 y 1000 obtenia mejores resultados
#
# ---

# %%
#from sklearn.neural_network import MLPClassifier
#from sklearn.feature_extraction.text import CountVectorizer

#vectorizer = CountVectorizer()
#X_train = vectorizer.fit_transform(texto_comentarios_training)
#X_test = vectorizer.transform(texto_comentarios_dev)

#model = MLPClassifier(hidden_layer_sizes=(300,), max_iter=3000, random_state=42)
#model.fit(X_train, ofensividad_comentarios_training)

# %%
#calculaPrecision(vectorizer,model)

# %% [markdown]
# ### Probando ajustar peso de las etiqueta segun numero de instancias en el mejor(class weight balanced)

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42,class_weight='balanced')
#model = DecisionTreeClassifier(random_state=42,class_weight={"NON": 1, "OFF": 100}) 
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)

# %%
calculaPrecision(vectorizer,model)
# Out:
# Precisión: 0.75
# Macro-f1 0.6415770609318996
# Recall 0.6314968814968815
#               precision    recall  f1-score   support
#
#          NON       0.80      0.88      0.84        74
#          OFF       0.53      0.38      0.44        26
#
#     accuracy                           0.75       100
#    macro avg       0.66      0.63      0.64       100
# weighted avg       0.73      0.75      0.74       100

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %% [markdown]
# **Creando ficheros**

# %%
from sklearn.feature_extraction.text import CountVectorizer

#Probando arbol de decision
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris

iris = load_iris()
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texto_comentarios_training)

# Crear un modelo de árbol de decisión y ajustarlo a los datos de entrenamiento
model = DecisionTreeClassifier(random_state=42)
model.fit(X, ofensividad_comentarios_training)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
with open("resultado_count_vectorizer_y_decision_tree_classifier.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['id', 'tclase'])
    
    off = 0
    non = 0
    for i, comentario in enumerate(comentarios_test):
        Y = vectorizer.transform([comentario["texto"]])
        prediction = model.predict(Y)
        if(prediction == 'OFF'):
            off = off+1
        else:
            non = non+1

        writer.writerow([comentario["id"], prediction[0]])

    print("Los resultados finales son: ",off, " comentarios ofensivos y ",non, " comentarios no ofensivos")
# Out:
# Los resultados finales son:  2151  comentarios ofensivos y  11434  comentarios no ofensivos

# %%
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
import csv

# Crear el vectorizador
vectorizer2 = TfidfVectorizer()
X_train_vectorized = vectorizer2.fit_transform(texto_comentarios_training)
X_dev_vectorized = vectorizer2.transform(texto_comentarios_dev)

# Entrenar el modelo SVM
modelSVMTfidf = svm.SVC(C=1, kernel='linear', gamma='scale')
modelSVMTfidf.fit(X_train_vectorized, ofensividad_comentarios_training)

# Realizar las predicciones en el conjunto de desarrollo
y_pred = modelSVMTfidf.predict(X_dev_vectorized)

# %%
with open("resultado_tfid_vectorizer_y_modelSVMTfidf.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['id', 'tclase'])
    
    off = 0
    non = 0
    for i, comentario in enumerate(comentarios_test):
        Y = vectorizer2.transform([comentario["texto"]])
        prediction = modelSVMTfidf.predict(Y)
        if(prediction == 'OFF'):
            off = off+1
        else:
            non = non+1

        writer.writerow([comentario["id"], prediction[0]])

    print("Los resultados finales son: ",off, " comentarios ofensivos y ",non, " comentarios no ofensivos")
# Out:
# Los resultados finales son:  1201  comentarios ofensivos y  12384  comentarios no ofensivos

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(texto_comentarios_training)
X_test = vectorizer.transform(texto_comentarios_dev)

model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
model.fit(X_train, ofensividad_comentarios_training)
# Out:
# MLPClassifier(max_iter=1000, random_state=42)

# %%
with open("resultado_red_neuronal.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['id', 'tclase'])
    
    off = 0
    non = 0
    for i, comentario in enumerate(comentarios_test):
        Y = vectorizer.transform([comentario["texto"]])
        prediction = model.predict(Y)
        if(prediction == 'OFF'):
            off = off+1
        else:
            non = non+1

        writer.writerow([comentario["id"], prediction[0]])

    print("Los resultados finales son: ",off, " comentarios ofensivos y ",non, " comentarios no ofensivos")
# Out:
# Los resultados finales son:  1944  comentarios ofensivos y  11641  comentarios no ofensivos
